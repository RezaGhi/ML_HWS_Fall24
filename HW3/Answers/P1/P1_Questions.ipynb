# %% [markdown]
# <b><h4>HW3 - Notebook: Multi-Layer perceptron</h4></b>
#
# [CE40477: Machine Learning](https://www.sharifml.ir/)
#
# __Course Instructor__: Dr. Sharifi-Zarchi
#
# __Notebook Authors__: Amir Ezzati & Ali Bavafa
#
# Name:Reza Ghorbani Paji
# Student-ID:403206565

# %% [markdown]
# # Import & Helper Functions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gdown
from sklearn.datasets import fetch_openml
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import time
import random

import torch
import torch.nn as nn
import torch.optim as optim

from torchvision import transforms
from torchvision.utils import make_grid
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, TensorDataset

from tqdm.auto import tqdm
from IPython.display import display

# %%
def seed_setter(seed=None, seed_torch=True):
  """
  Function that controls randomness.

  Args:
    seed : Integer
      A non-negative integer that defines the random state.
    seed_torch : Boolean
      If `True` sets the random seed for pytorch tensors.

  Returns:
    Nothing.
  """
  if seed is None:
    seed = np.random.choice(2 ** 32)
  random.seed(seed)
  np.random.seed(seed)
  if seed_torch:
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

  print(f'Random seed {seed} has been set.')


# In case that `DataLoader` is used
def seed_worker(worker_id):

  worker_seed = torch.initial_seed() % 2**32
  np.random.seed(worker_seed)
  random.seed(worker_seed)


def train_test_classification(net, criterion, optimizer, train_loader,
                              test_loader, num_epochs=1, verbose=True,
                              training_plot=False):
  """
  Accumulate training loss/Evaluate performance

  Args:
    net: Instance of Net class
      Describes the model with ReLU activation, batch size 128
    criterion: torch.nn type
      Criterion combines LogSoftmax and NLLLoss in one single class.
    optimizer: torch.optim type
      Implements Adam algorithm.
    train_loader: torch.utils.data type
      Combines the train dataset and sampler, and provides an iterable over the given dataset.
    test_loader: torch.utils.data type
      Combines the test dataset and sampler, and provides an iterable over the given dataset.
    num_epochs: int
      Number of epochs [default: 1]
    verbose: boolean
      If True, print statistics
    training_plot=False
      If True, display training plot

  Returns:
    Nothing
  """
  net.train()
  train_losses = []
  for epoch in tqdm(range(num_epochs)):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
      # Get the inputs; data is a list of [inputs, labels]
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      optimizer.zero_grad()
      outputs = net(inputs)

      loss = criterion(outputs, labels)
      loss.backward()
      optimizer.step()

      if verbose:
        train_losses += [loss.item()]

  net.eval()

  def test(data_loader):
    """
    Function to gauge network performance

    Args:
      data_loader: torch.utils.data type
        Combines the test dataset and sampler, and provides an iterable over the given dataset.

    Returns:
      acc: float
        Performance of the network
      total: int
        Number of datapoints in the dataloader
    """
    correct = 0
    total = 0
    for data in data_loader:
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      outputs = net(inputs)
      _, predicted = torch.max(outputs, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

    acc = 100 * correct / total
    return total, acc

  train_total, train_acc = test(train_loader)
  test_total, test_acc = test(test_loader)

  if verbose:
    print(f'\nAccuracy on the {train_total} training samples: {train_acc:0.2f}')
    print(f'Accuracy on the {test_total} testing samples: {test_acc:0.2f}\n')

  if training_plot:
    plt.plot(train_losses)
    plt.xlabel('Batch')
    plt.ylabel('Training loss')
    plt.show()

  return train_acc, test_acc


def shuffle_and_split_data(X, y, seed):
  """
  Helper function to shuffle and split data

  Args:
    X: torch.tensor
      Input data
    y: torch.tensor
      Corresponding target variables
    seed: int
      Set seed for reproducibility

  Returns:
    X_test: torch.tensor
      Test data [20% of X]
    y_test: torch.tensor
      Labels corresponding to above mentioned test data
    X_train: torch.tensor
      Train data [80% of X]
    y_train: torch.tensor
      Labels corresponding to above mentioned train data
  """
  # Set seed for reproducibility
  torch.manual_seed(seed)
  # Number of samples
  N = X.shape[0]
  # Shuffle data
  shuffled_indices = torch.randperm(N)
  X = X[shuffled_indices]
  y = y[shuffled_indices]

  test_size = int(0.2 * N)
  X_test = X[:test_size]
  y_test = y[:test_size]
  X_train = X[test_size:]
  y_train = y[test_size:]

  return X_test, y_test, X_train, y_train


def sample_grid(M=500, x_max=2.0):
  """
  Helper function to simulate sample meshgrid

  Args:
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points

  Returns:
    X_all: torch.tensor
      Concatenated meshgrid tensor
  """
  ii, jj = torch.meshgrid(torch.linspace(-x_max, x_max,M),
                          torch.linspace(-x_max, x_max, M),
                          indexing='ij')
  X_all = torch.cat([ii.unsqueeze(-1),
                     jj.unsqueeze(-1)],
                     dim=-1).view(-1, 2)
  return X_all


def plot_decision_map(X_all, y_pred, X_test, y_test,
                      M=500, x_max=2.0, eps=1e-3):
  """
  Helper function to plot decision map

  Args:
    X_all: torch.tensor
      Concatenated meshgrid tensor
    y_pred: torch.tensor
      Labels predicted by the network
    X_test: torch.tensor
      Test data
    y_test: torch.tensor
      Labels of the test data
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points
    eps: float
      Decision threshold

  Returns:
    Nothing
  """
  decision_map = torch.argmax(y_pred, dim=1)

  for i in range(len(X_test)):
    indeces = (X_all[:, 0] - X_test[i, 0])**2 + (X_all[:, 1] - X_test[i, 1])**2 < eps
    decision_map[indeces] = (K + y_test[i]).long()

  decision_map = decision_map.view(M, M).cpu()
  plt.imshow(decision_map, extent=[-x_max, x_max, -x_max, x_max], cmap='jet')
  plt.axis('off')
  plt.plot()


def plot_function_apx(x_vals, relu_activations, predicted_output):
    """
    Visualizes ReLU activations and the resulting function approximation.

    Args:
      x_vals: torch.tensor
        Input x-axis data points.
      relu_activations: torch.tensor
        Calculated ReLU activations along x-axis for each ReLU unit.
      predicted_output: torch.tensor
        Estimated output labels or function approximations (weighted sum of ReLUs).

    Returns:
      None
    """

    fig, axes = plt.subplots(2, 1, figsize=(8, 6))

    ## Plot ReLU activations
    axes[0].plot(x_vals, relu_activations.T)
    axes[0].set_xlabel('x-values', fontsize=12)
    axes[0].set_ylabel('Activation Levels', fontsize=12)
    axes[0].set_title('ReLU Activations (Basis Functions)', fontsize=14)
    relu_labels = [f"ReLU {i + 1}" for i in range(relu_activations.shape[0])]
    axes[0].legend(relu_labels, ncol=2)

    ## Plot the function approximation and the ground truth
    axes[1].plot(x_vals, torch.sin(x_vals), label='Ground Truth (sin(x))', color='g', linewidth=2)
    axes[1].plot(x_vals, predicted_output, label='Predicted Output', linestyle='--', color='r')
    axes[1].set_xlabel('x-values', fontsize=12)
    axes[1].set_ylabel('y(x)', fontsize=12)
    axes[1].set_title('Function Approximation vs Ground Truth', fontsize=14)
    axes[1].legend()

    plt.tight_layout(pad=2)
    plt.show()


def show_images(image, num_row=2, num_col=5):
    # plot images
    image_size = int(np.sqrt(image.shape[-1]))
    image = np.reshape(image, (image.shape[0], image_size, image_size))
    fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
    for i in range(num_row*num_col):
        ax = axes[i//num_col, i%num_col]
        ax.imshow(image[i], cmap='gray', vmin=0, vmax=1)
        ax.axis('off')
    plt.tight_layout()
    plt.show()


SEED = 2024
# Call `seed_setter` to ensure reproducibility.
seed_setter(seed=SEED)
# Out:
# Random seed 2024 has been set.

# %% [markdown]
# # Loading the data

# %%
# Load data
mnist_data = fetch_openml("mnist_784")
x = mnist_data["data"].astype('float').to_numpy()
y = mnist_data["target"].astype('int')

# Normalize
x /= 255.0

# One-hot encode labels
num_labels = len(np.unique(y))
y_new = to_categorical(y, num_labels)

# %%
x.shape
# Out:
# (70000, 784)

# %%
# -------------------------------- TODO -------------------------------------
x_train = x[:60000]
y_train = y_new[:60000]
x_test = x[60000:]
y_test = y_new[60000:]
# -------------------------------- TODO -------------------------------------

# %%
print("Training data: {} {}".format(x_train.shape, y_train.shape))
print("Test data: {} {}".format(x_test.shape, y_test.shape))
show_images(x_train)
# Out:
# Training data: (60000, 784) (60000, 10)
# Test data: (10000, 784) (10000, 10)

# %% [markdown]
# # Activation Functions & Optimizers

# %% [markdown]
# There are many activation functions which some of them listed below. In this section you should implement them.
#
# 1. Sigmoid:
# $$
# \operatorname{sigmoid}(x) = \frac{1}{1 + \exp(-x)}
# $$
#
# 2. Softmax: $$\operatorname{softmax}(\mathbf X)_{ij} = \frac{\exp(\mathbf X_{ij})}{\sum_k \exp \mathbf X_{ik})}.$$
#
#
# 3. Tanh (Hyperbolic Tangent):
# $$
# \operatorname{tanh}(x) = \frac{\sinh(x)}{\cosh(x)} = \frac{\exp(x) - \exp(-x)}{\exp(x) + \exp(-x)}
# $$
#
# 4. ReLU: $$\operatorname{ReLU}(x) = \max(0, x)$$
#
# 5. Leaky ReLU:
# $$
# \operatorname{LeakyReLU}(x) =
# \begin{cases}
# x & \text{if } x \geq 0 \\
# \alpha x & \text{if } x < 0
# \end{cases}
# $$
# where \( $\alpha$ \) is a small constant (e.g., 0.01).
#
# 6. ELU (Exponential Linear Unit):
# $$
# \operatorname{ELU}(x) =
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where ($\alpha$) is a positive constant.
#
# 7. SELU (Scaled Exponential Linear Unit):
# $$
# \operatorname{SELU}(x) =
# \lambda
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where \( $\lambda$ \) and \( $\alpha$ \) are predefined constants, typically \( $\lambda \approx 1.0507$ \) and \( $\alpha \approx 1.67326$ \).

# %% [markdown]
# ------
# There are several optimizer algorithms for optimizing the neural network over epochs. You should implement some of those mentioned in this section:
#
# ***Stochastic Gradient Descent (SGD)***
#
# SGD is the basic form of gradient descent, where each weight (\( w \)) and bias (\( b \)) parameter is updated in the opposite direction of its gradient.
#
# **Update Rule:**
# $$
# w^{(t+1)} = w^{(t)} - \eta \cdot \nabla_w L(w^{(t)}, b^{(t)})
# $$
# $$
# b^{(t+1)} = b^{(t)} - \eta \cdot \nabla_b L(w^{(t)}, b^{(t)})
# $$
#
# - \( w \): Weight parameters
# - \( b \): Bias parameters
# - \( $\eta$ \): Learning rate
# - \( $\nabla_w L(w, b)$ \): Gradient of the loss with respect to \( w \)
# - \( $\nabla_b L(w, b)$ \): Gradient of the loss with respect to \( b \)
#
# <br><br>
#
# ***Momentum Optimizer***
#
# Momentum optimizer smooths parameter updates by adding a velocity term to accumulate past gradients.
#
# **Update Rule:**
# 1. **Velocity Update for Weights and Biases:**
#    $$
#    v_w^{(t+1)} = \beta \cdot v_w^{(t)} + (1 - \beta) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_b^{(t+1)} = \beta \cdot v_b^{(t)} + (1 - \beta) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#
# 2. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot v_w^{(t+1)}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot v_b^{(t+1)}
#    $$
#
# - \( $v_w$ \): Velocity term for weights
# - \( $v_b$ \): Velocity term for biases
# - \( $\beta$ \): Momentum term, typically set to 0.9
#
# <br><br>
#
# ***Adam Optimizer***
#
# Adam combines momentum and adaptive learning rates, using both first (momentum) and second (RMSprop) moment estimates.
#
# **Update Rule:**
# 1. **Compute biased first and second moment estimates:**
#    $$
#    m_w^{(t+1)} = \beta_1 \cdot m_w^{(t)} + (1 - \beta_1) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    m_b^{(t+1)} = \beta_1 \cdot m_b^{(t)} + (1 - \beta_1) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_w^{(t+1)} = \beta_2 \cdot v_w^{(t)} + (1 - \beta_2) \cdot \left( \nabla_w L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#    $$
#    v_b^{(t+1)} = \beta_2 \cdot v_b^{(t)} + (1 - \beta_2) \cdot \left( \nabla_b L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#
# 2. **Compute bias-corrected estimates:**
#    $$
#    \hat{m}_w^{(t+1)} = \frac{m_w^{(t+1)}}{1 - \beta_1^{t+1}}, \quad \hat{m}_b^{(t+1)} = \frac{m_b^{(t+1)}}{1 - \beta_1^{t+1}}
#    $$
#    $$
#    \hat{v}_w^{(t+1)} = \frac{v_w^{(t+1)}}{1 - \beta_2^{t+1}}, \quad \hat{v}_b^{(t+1)} = \frac{v_b^{(t+1)}}{1 - \beta_2^{t+1}}
#    $$
#
# 3. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot \frac{\hat{m}_w^{(t+1)}}{\sqrt{\hat{v}_w^{(t+1)}} + \epsilon}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot \frac{\hat{m}_b^{(t+1)}}{\sqrt{\hat{v}_b^{(t+1)}} + \epsilon}
#    $$
#
# - \( $m_w$ \), \( $m_b$ \): First moment estimates (mean of gradients) for weights and biases
# - \( $v_w$ \), \( $v_b$ \): Second moment estimates (uncentered variance of gradients) for weights and biases
# - \( $\beta_1$ \): Decay rate for first moment, typically 0.9
# - \( $\beta_2$ \): Decay rate for second moment, typically 0.999
# - \( $\epsilon$ \): Small constant for numerical stability (e.g., \(10^{-8}\))

# %% [markdown]
# # MLP from Scratch

# %%
import numpy as np
import time

class MLP():
    def __init__(self, sizes, activation='sigmoid'):
        self.sizes = sizes
        self.num_layers = len(sizes) - 1  # number of layers excluding input
        self.activation_name = activation

        # Choose activation function
        if activation == 'relu':
            self.activation = self.relu
        elif activation == 'sigmoid':
            self.activation = self.sigmoid
        elif activation == 'tanh':
            self.activation = self.tanh
        # Added other activation functions
        elif activation == 'leaky_relu':
            self.activation = self.leaky_relu
        elif activation == 'elu':
            self.activation = self.elu
        elif activation == 'selu':
            self.activation = self.selu
        else:
            raise ValueError("This activation function is currently not supported!")

        # Save all weights
        self.params = self.initialize()
        # Save all intermediate values, i.e. activations
        self.cache = {}

    # Activation functions
    def relu(self, x, derivative=False):
        '''
            Forward path:
            relu(x) = max(0, x)

            Backward path:
            ∇relu(x) = 0, if x < 0
                     = 1, if x >= 0
        '''
        if derivative:
            return np.where(x > 0, 1, 0)
        else:
            return np.maximum(0, x)

    def tanh(self, x, derivative=False):
        '''
            Forward path:
            tanh(x) = (exp(x) - exp(-x)) / (exp(x) + exp(-x))

            Backward path:
            ∇tanh(x) = 1 - tanh(x)^2
        '''
        if derivative:
            return 1 - np.tanh(x) ** 2
        else:
            return np.tanh(x)

    def sigmoid(self, x, derivative=False):
        '''
            Forward path:
            σ(x) = 1 / (1 + exp(-x))

            Backward path:
            ∇σ(x) = σ(x) * (1 - σ(x))
        '''
        if derivative:
            sig = self.sigmoid(x)
            return sig * (1 - sig)
        else:
            return 1 / (1 + np.exp(-x))

    def softmax(self, x):
        '''
            softmax(x) = exp(x) / ∑exp(x)
        '''
        # Numerically stable with large exponentials
        x_shifted = x - np.max(x, axis=0, keepdims=True)
        exps = np.exp(x_shifted)
        return exps / np.sum(exps, axis=0, keepdims=True)

    def leaky_relu(self, x, alpha=0.01, derivative=False):
        '''
            Forward path:
            leaky_relu(x) = x if x >= 0 else αx

            Backward path:
            ∇leaky_relu(x) = 1 if x >= 0 else α
        '''
        if derivative:
            return np.where(x >= 0, 1, alpha)
        else:
            return np.where(x >= 0, x, alpha * x)

    def elu(self, x, alpha=1.0, derivative=False):
        '''
            Forward path:
            elu(x) = x if x > 0 else α(exp(x) - 1)

            Backward path:
            ∇elu(x) = 1 if x > 0 else α * exp(x)
        '''
        if derivative:
            return np.where(x > 0, 1, alpha * np.exp(x))
        else:
            return np.where(x > 0, x, alpha * (np.exp(x) - 1))

    def selu(self, x, lambda_=1.0507, alpha=1.67326, derivative=False):
        '''
            Forward path:
            selu(x) = λ * (x if x > 0 else α * (exp(x) - 1))

            Backward path:
            ∇selu(x) = λ * (1 if x > 0 else α * exp(x))
        '''
        if derivative:
            return lambda_ * np.where(x > 0, 1, alpha * np.exp(x))
        else:
            return lambda_ * np.where(x > 0, x, alpha * (np.exp(x) - 1))

    def initialize(self):
        params = {}
        for i in range(1, self.num_layers + 1):
            input_layer = self.sizes[i - 1]
            output_layer = self.sizes[i]
            params[f"W{i}"] = np.random.randn(output_layer, input_layer) * np.sqrt(1. / input_layer)
            params[f"b{i}"] = np.zeros((output_layer, 1))
        return params

    def feed_forward(self, x):
        self.cache["A0"] = x.T
        # Perform feedforward pass through each hidden layer
        for i in range(1, self.num_layers + 1):
            W = self.params[f"W{i}"]
            b = self.params[f"b{i}"]
            Z = np.dot(W, self.cache[f"A{i-1}"]) + b
            self.cache[f"Z{i}"] = Z

            if i == self.num_layers:
                # Output layer with softmax activation
                A = self.softmax(Z)
                self.cache[f"A{i}"] = A
            else:
                # Hidden layers with chosen activation function
                A = self.activation(Z)
                self.cache[f"A{i}"] = A
        return self.cache[f"A{self.num_layers}"]

    def back_propagate(self, y, output):
        m = y.shape[0]
        grads = {}
        y = y.T  # Transpose to match dimensions
        dZ = output - y  # Derivative of loss w.r.t Z at output layer

        # Backpropagate through layers
        for i in reversed(range(1, self.num_layers + 1)):
            A_prev = self.cache[f"A{i-1}"]
            W = self.params[f"W{i}"]

            # Gradients of weights and biases
            grads[f"W{i}"] = (1/m) * np.dot(dZ, A_prev.T)
            grads[f"b{i}"] = (1/m) * np.sum(dZ, axis=1, keepdims=True)

            if i > 1:
                # Propagate the gradient to previous layer
                dA_prev = np.dot(W.T, dZ)
                Z_prev = self.cache[f"Z{i-1}"]
                dZ = dA_prev * self.activation(Z_prev, derivative=True)
        self.grads = grads
        return self.grads

    def cross_entropy_loss(self, y, output):
        '''
            L(y, ŷ) = −∑ylog(ŷ).
        '''
        # Compute cross-entropy loss
        m = y.shape[0]
        y = y.T
        loss = -np.sum(y * np.log(output + 1e-8)) / m  # Added epsilon to prevent log(0)
        return loss

    def initialize_momemtum_optimizer(self):
        momemtum_opt = {}
        for i in range(1, self.num_layers + 1):
            # Initialize zero matrices for momentum updates
            momemtum_opt[f"vW{i}"] = np.zeros_like(self.params[f"W{i}"])
            momemtum_opt[f"vb{i}"] = np.zeros_like(self.params[f"b{i}"])
        return momemtum_opt

    def initialize_adam_optimizer(self):
        adam_opt = {}
        for i in range(1, self.num_layers + 1):
            # Initialize zero matrices for Adam optimizer
            adam_opt[f"mW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"vW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"mb{i}"] = np.zeros_like(self.params[f"b{i}"])
            adam_opt[f"vb{i}"] = np.zeros_like(self.params[f"b{i}"])
        return adam_opt

    def optimize(self, l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):
        if self.optimizer == "sgd":
            for i in range(1, self.num_layers + 1):
                # Update rule for SGD
                self.params[f"W{i}"] -= l_rate * self.grads[f"W{i}"]
                self.params[f"b{i}"] -= l_rate * self.grads[f"b{i}"]
        elif self.optimizer == "momentum":
            for i in range(1, self.num_layers + 1):
                # Update rule for Momentum
                self.momemtum_opt[f"vW{i}"] = beta * self.momemtum_opt[f"vW{i}"] + (1 - beta) * self.grads[f"W{i}"]
                self.momemtum_opt[f"vb{i}"] = beta * self.momemtum_opt[f"vb{i}"] + (1 - beta) * self.grads[f"b{i}"]
                self.params[f"W{i}"] -= l_rate * self.momemtum_opt[f"vW{i}"]
                self.params[f"b{i}"] -= l_rate * self.momemtum_opt[f"vb{i}"]
        elif self.optimizer == "adam":
            for i in range(1, self.num_layers + 1):
                # Update rule for Adam
                # First moment estimate
                self.adam_opt[f"mW{i}"] = beta1 * self.adam_opt[f"mW{i}"] + (1 - beta1) * self.grads[f"W{i}"]
                self.adam_opt[f"mb{i}"] = beta1 * self.adam_opt[f"mb{i}"] + (1 - beta1) * self.grads[f"b{i}"]
                # Second moment estimate
                self.adam_opt[f"vW{i}"] = beta2 * self.adam_opt[f"vW{i}"] + (1 - beta2) * (self.grads[f"W{i}"] ** 2)
                self.adam_opt[f"vb{i}"] = beta2 * self.adam_opt[f"vb{i}"] + (1 - beta2) * (self.grads[f"b{i}"] ** 2)
                # Bias correction
                mW_hat = self.adam_opt[f"mW{i}"] / (1 - beta1 ** t)
                mb_hat = self.adam_opt[f"mb{i}"] / (1 - beta1 ** t)
                vW_hat = self.adam_opt[f"vW{i}"] / (1 - beta2 ** t)
                vb_hat = self.adam_opt[f"vb{i}"] / (1 - beta2 ** t)
                # Update parameters
                self.params[f"W{i}"] -= l_rate * mW_hat / (np.sqrt(vW_hat) + epsilon)
                self.params[f"b{i}"] -= l_rate * mb_hat / (np.sqrt(vb_hat) + epsilon)
        else:
            raise ValueError("This optimizer is currently not supported!")

    def accuracy(self, y, output):
        # Calculate accuracy by comparing predictions with true labels
        preds = np.argmax(output, axis=0)
        labels = np.argmax(y.T, axis=0)
        return np.mean(preds == labels)

    def train(self, x_train, y_train, x_val, y_val, epochs=10,
              batch_size=64, optimizer='momentum', l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8):
        # Hyperparameters
        self.epochs = epochs
        self.batch_size = batch_size
        num_batches = -(-x_train.shape[0] // self.batch_size)  # Ceiling division

        # Initialize optimizer
        self.optimizer = optimizer
        if self.optimizer == 'momentum':
            self.momemtum_opt = self.initialize_momemtum_optimizer()
        elif self.optimizer == 'adam':
            self.adam_opt = self.initialize_adam_optimizer()

        start_time = time.time()
        t = 1  # Time step for optimizers like Adam

        # Train
        for i in range(self.epochs):
            # Shuffle the training data
            permutation = np.random.permutation(x_train.shape[0])
            x_train_shuffled = x_train[permutation]
            y_train_shuffled = y_train[permutation]

            for j in range(num_batches):
                # Get mini-batch
                begin = j * self.batch_size
                end = min(begin + self.batch_size, x_train.shape[0])
                x = x_train_shuffled[begin:end]
                y = y_train_shuffled[begin:end]

                # Forward propagation
                output = self.feed_forward(x)
                # Backward propagation
                grad = self.back_propagate(y, output)
                # Parameter update
                self.optimize(l_rate=l_rate, beta=beta, beta1=beta1, beta2=beta2, epsilon=epsilon, t=t)
                t += 1  # Increment time step

            # Evaluate performance after each epoch
            output_train = self.feed_forward(x_train)
            train_acc = self.accuracy(y_train, output_train)
            train_loss = self.cross_entropy_loss(y_train, output_train)
            output_val = self.feed_forward(x_val)
            val_acc = self.accuracy(y_val, output_val)
            val_loss = self.cross_entropy_loss(y_val, output_val)
            print(f'Epoch {i+1}: {time.time()-start_time:.2f}s, train acc={train_acc:.2f}, train loss={train_loss:.2f}, '
                  f'validation acc={val_acc:.2f}, validation loss={val_loss:.2f}')

    def evaluate(self, x_test, y_test):
        # Evaluate on test data
        output = self.feed_forward(x_test)
        test_acc = self.accuracy(y_test, output)
        test_loss = self.cross_entropy_loss(y_test, output)
        print(f'\nTest acc={test_acc:.2f}, Test loss={test_loss:.2f}')

# %% [markdown]
# Please run experiments with different combinations of optimizers (SGD, Momentum, and Adam) and activation functions (ReLU, Sigmoid, Tanh, Leaky ReLU, SELU, and ELU) over 20 epochs each. Consider networks with three layers (without input layer) whose number of neurons is 128, 64 and 10 respectively. Also consider two learning rates 0.01 and 0.001.
#
#
# After testing all combinations, report which combination of optimizer, activation function, and learning rate performs best.
#
#
#  Activation=sigmoid, Optimizer=adam, Learning Rate=0.001

# %%
# Define the network architecture
sizes = [x_train.shape[1], 128, 64, 10]  # Replace input_size with the number of features in your dataset

# Define activation functions and optimizers to test
activation_functions = ['relu', 'sigmoid', 'tanh', 'leaky_relu', 'selu', 'elu']
optimizers = ['sgd', 'momentum', 'adam']
learning_rates = [0.01, 0.001]

# Loop over all combinations
for activation in activation_functions:
    for optimizer in optimizers:
        for l_rate in learning_rates:
            print(f"\nTesting combination: Activation={activation}, Optimizer={optimizer}, Learning Rate={l_rate}")
            # Initialize the MLP
            mlp = MLP(sizes, activation=activation)
            # Train the model
            mlp.train(x_train, y_train, x_test, y_test,
                      epochs=20,
                      batch_size=64,
                      optimizer=optimizer,
                      l_rate=l_rate)
            # Evaluate on validation data
            mlp.evaluate(x_test, y_test)
# Out:
# Testing combination: Activation=relu, Optimizer=sgd, Learning Rate=0.01
# Epoch 1: 5.46s, train acc=0.87, train loss=0.48, validation acc=0.88, validation loss=0.46
# Epoch 2: 8.70s, train acc=0.90, train loss=0.35, validation acc=0.91, validation loss=0.34
# Epoch 3: 11.91s, train acc=0.91, train loss=0.30, validation acc=0.92, validation loss=0.30
# Epoch 4: 16.35s, train acc=0.92, train loss=0.28, validation acc=0.92, validation loss=0.27
# Epoch 5: 20.22s, train acc=0.93, train loss=0.26, validation acc=0.93, validation loss=0.25
# Epoch 6: 23.38s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.24
# Epoch 7: 26.60s, train acc=0.94, train loss=0.22, validation acc=0.94, validation loss=0.22
# Epoch 8: 31.41s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.21
# Epoch 9: 35.11s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.20
# Epoch 10: 38.31s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.19
# Epoch 11: 41.49s, train acc=0.95, train loss=0.18, validation acc=0.95, validation loss=0.18
# Epoch 12: 46.95s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.17
# Epoch 13: 50.24s, train acc=0.96, train loss=0.16, validation acc=0.95, validation loss=0.16
# Epoch 14: 53.43s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.16
# Epoch 15: 56.66s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.15
# Epoch 16: 62.15s, train acc=0.96, train loss=0.14, validation acc=0.96, validation loss=0.15
# Epoch 17: 65.37s, train acc=0.96, train loss=0.13, validation acc=0.96, validation loss=0.14
# Epoch 18: 68.61s, train acc=0.97, train loss=0.12, validation acc=0.96, validation loss=0.14
# Epoch 19: 72.35s, train acc=0.97, train loss=0.12, validation acc=0.96, validation loss=0.13
# Epoch 20: 77.11s, train acc=0.97, train loss=0.11, validation acc=0.96, validation loss=0.13
#
# Test acc=0.96, Test loss=0.13
#
# Testing combination: Activation=relu, Optimizer=sgd, Learning Rate=0.001
# Epoch 1: 3.21s, train acc=0.44, train loss=2.09, validation acc=0.44, validation loss=2.08
# Epoch 2: 6.43s, train acc=0.65, train loss=1.70, validation acc=0.66, validation loss=1.69
# Epoch 3: 10.94s, train acc=0.75, train loss=1.27, validation acc=0.75, validation loss=1.25
# Epoch 4: 14.86s, train acc=0.79, train loss=0.95, validation acc=0.80, validation loss=0.94
# Epoch 5: 18.09s, train acc=0.82, train loss=0.77, validation acc=0.83, validation loss=0.75
# Epoch 6: 21.27s, train acc=0.84, train loss=0.66, validation acc=0.84, validation loss=0.64
# Epoch 7: 26.57s, train acc=0.85, train loss=0.59, validation acc=0.86, validation loss=0.57
# Epoch 8: 29.91s, train acc=0.86, train loss=0.53, validation acc=0.87, validation loss=0.52
# Epoch 9: 33.10s, train acc=0.87, train loss=0.50, validation acc=0.87, validation loss=0.48
# Epoch 10: 36.28s, train acc=0.88, train loss=0.47, validation acc=0.88, validation loss=0.45
# Epoch 11: 41.88s, train acc=0.88, train loss=0.45, validation acc=0.88, validation loss=0.43
# Epoch 12: 45.11s, train acc=0.89, train loss=0.43, validation acc=0.89, validation loss=0.41
# Epoch 13: 48.32s, train acc=0.89, train loss=0.41, validation acc=0.89, validation loss=0.40
# Epoch 14: 51.53s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.39
# Epoch 15: 56.94s, train acc=0.89, train loss=0.39, validation acc=0.90, validation loss=0.38
# Epoch 16: 60.13s, train acc=0.89, train loss=0.38, validation acc=0.90, validation loss=0.37
# Epoch 17: 63.33s, train acc=0.90, train loss=0.37, validation acc=0.90, validation loss=0.36
# Epoch 18: 66.97s, train acc=0.90, train loss=0.36, validation acc=0.90, validation loss=0.35
# Epoch 19: 71.72s, train acc=0.90, train loss=0.36, validation acc=0.90, validation loss=0.34
# Epoch 20: 75.04s, train acc=0.90, train loss=0.35, validation acc=0.90, validation loss=0.34
#
# Test acc=0.90, Test loss=0.34
#
# Testing combination: Activation=relu, Optimizer=momentum, Learning Rate=0.01
# Epoch 1: 3.58s, train acc=0.88, train loss=0.48, validation acc=0.88, validation loss=0.46
# Epoch 2: 9.48s, train acc=0.90, train loss=0.35, validation acc=0.91, validation loss=0.33
# Epoch 3: 13.07s, train acc=0.91, train loss=0.30, validation acc=0.92, validation loss=0.29
# Epoch 4: 16.60s, train acc=0.92, train loss=0.28, validation acc=0.93, validation loss=0.27
# Epoch 5: 21.32s, train acc=0.93, train loss=0.26, validation acc=0.93, validation loss=0.25
# Epoch 6: 25.78s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.23
# Epoch 7: 29.34s, train acc=0.94, train loss=0.22, validation acc=0.94, validation loss=0.22
# Epoch 8: 32.98s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.21
# Epoch 9: 38.87s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.20
# Epoch 10: 42.49s, train acc=0.95, train loss=0.19, validation acc=0.95, validation loss=0.18
# Epoch 11: 46.17s, train acc=0.95, train loss=0.18, validation acc=0.95, validation loss=0.18
# Epoch 12: 52.24s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.17
# Epoch 13: 55.90s, train acc=0.95, train loss=0.16, validation acc=0.95, validation loss=0.16
# Epoch 14: 59.53s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.16
# Epoch 15: 64.41s, train acc=0.96, train loss=0.14, validation acc=0.96, validation loss=0.15
# Epoch 16: 68.85s, train acc=0.96, train loss=0.14, validation acc=0.96, validation loss=0.14
# Epoch 17: 72.54s, train acc=0.96, train loss=0.13, validation acc=0.96, validation loss=0.14
# Epoch 18: 76.19s, train acc=0.96, train loss=0.13, validation acc=0.96, validation loss=0.14
# Epoch 19: 81.73s, train acc=0.97, train loss=0.12, validation acc=0.96, validation loss=0.13
# Epoch 20: 85.39s, train acc=0.97, train loss=0.11, validation acc=0.96, validation loss=0.13
#
# Test acc=0.96, Test loss=0.13
#
# Testing combination: Activation=relu, Optimizer=momentum, Learning Rate=0.001
# Epoch 1: 3.59s, train acc=0.51, train loss=2.08, validation acc=0.51, validation loss=2.07
# Epoch 2: 9.92s, train acc=0.67, train loss=1.74, validation acc=0.67, validation loss=1.73
# Epoch 3: 13.59s, train acc=0.75, train loss=1.32, validation acc=0.76, validation loss=1.30
# Epoch 4: 17.19s, train acc=0.80, train loss=0.98, validation acc=0.81, validation loss=0.96
# Epoch 5: 23.24s, train acc=0.82, train loss=0.78, validation acc=0.84, validation loss=0.76
# Epoch 6: 26.82s, train acc=0.84, train loss=0.66, validation acc=0.86, validation loss=0.64
# Epoch 7: 30.49s, train acc=0.86, train loss=0.58, validation acc=0.87, validation loss=0.56
# Epoch 8: 35.05s, train acc=0.87, train loss=0.53, validation acc=0.88, validation loss=0.51
# Epoch 9: 39.81s, train acc=0.87, train loss=0.49, validation acc=0.88, validation loss=0.47
# Epoch 10: 43.38s, train acc=0.88, train loss=0.46, validation acc=0.89, validation loss=0.44
# Epoch 11: 46.97s, train acc=0.88, train loss=0.44, validation acc=0.89, validation loss=0.42
# Epoch 12: 53.04s, train acc=0.89, train loss=0.42, validation acc=0.89, validation loss=0.40
# Epoch 13: 56.71s, train acc=0.89, train loss=0.41, validation acc=0.90, validation loss=0.39
# Epoch 14: 60.36s, train acc=0.89, train loss=0.39, validation acc=0.90, validation loss=0.38
# Epoch 15: 66.27s, train acc=0.89, train loss=0.38, validation acc=0.90, validation loss=0.37
# Epoch 16: 69.94s, train acc=0.90, train loss=0.37, validation acc=0.90, validation loss=0.36
# Epoch 17: 73.56s, train acc=0.90, train loss=0.36, validation acc=0.90, validation loss=0.35
# Epoch 18: 78.64s, train acc=0.90, train loss=0.36, validation acc=0.91, validation loss=0.34
# Epoch 19: 83.04s, train acc=0.90, train loss=0.35, validation acc=0.91, validation loss=0.34
# Epoch 20: 86.71s, train acc=0.90, train loss=0.35, validation acc=0.91, validation loss=0.33
#
# Test acc=0.91, Test loss=0.33
#
# Testing combination: Activation=relu, Optimizer=adam, Learning Rate=0.01
# Epoch 1: 5.95s, train acc=0.96, train loss=0.13, validation acc=0.95, validation loss=0.16
# Epoch 2: 11.52s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.14
# Epoch 3: 16.26s, train acc=0.97, train loss=0.12, validation acc=0.96, validation loss=0.16
# Epoch 4: 23.44s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.13
# Epoch 5: 28.34s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.15
# Epoch 6: 33.40s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.18
# Epoch 7: 39.75s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.15
# Epoch 8: 46.07s, train acc=0.97, train loss=0.09, validation acc=0.96, validation loss=0.16
# Epoch 9: 54.31s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.14
# Epoch 10: 60.90s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.18
# Epoch 11: 69.08s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.16
# Epoch 12: 76.52s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.17
# Epoch 13: 84.05s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.18
# Epoch 14: 92.27s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.16
# Epoch 15: 99.46s, train acc=0.98, train loss=0.10, validation acc=0.96, validation loss=0.21
# Epoch 16: 108.37s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.16
# Epoch 17: 114.98s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.16
# Epoch 18: 123.76s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.15
# Epoch 19: 130.59s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.16
# Epoch 20: 139.47s, train acc=0.99, train loss=0.03, validation acc=0.98, validation loss=0.16
#
# Test acc=0.98, Test loss=0.16
#
# Testing combination: Activation=relu, Optimizer=adam, Learning Rate=0.001
# Epoch 1: 4.75s, train acc=0.96, train loss=0.13, validation acc=0.96, validation loss=0.13
# Epoch 2: 12.05s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.10
# Epoch 3: 16.82s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.09
# Epoch 4: 22.59s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.08
# Epoch 5: 28.39s, train acc=0.99, train loss=0.04, validation acc=0.98, validation loss=0.08
# Epoch 6: 33.11s, train acc=0.99, train loss=0.02, validation acc=0.98, validation loss=0.08
# Epoch 7: 40.21s, train acc=0.99, train loss=0.02, validation acc=0.98, validation loss=0.07
# Epoch 8: 45.01s, train acc=0.99, train loss=0.02, validation acc=0.98, validation loss=0.08
# Epoch 9: 50.69s, train acc=0.99, train loss=0.02, validation acc=0.98, validation loss=0.08
# Epoch 10: 56.99s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.09
# Epoch 11: 61.88s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.08
# Epoch 12: 69.48s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.09
# Epoch 13: 74.57s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.10
# Epoch 14: 81.08s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.09
# Epoch 15: 86.91s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.10
# Epoch 16: 92.00s, train acc=0.99, train loss=0.02, validation acc=0.98, validation loss=0.11
# Epoch 17: 99.24s, train acc=0.99, train loss=0.01, validation acc=0.97, validation loss=0.12
# Epoch 18: 104.27s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.10
# Epoch 19: 111.84s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.10
# Epoch 20: 116.90s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.12
#
# Test acc=0.98, Test loss=0.12
#
# Testing combination: Activation=sigmoid, Optimizer=sgd, Learning Rate=0.01
# Epoch 1: 3.81s, train acc=0.28, train loss=2.25, validation acc=0.28, validation loss=2.25
# Epoch 2: 10.05s, train acc=0.46, train loss=2.16, validation acc=0.46, validation loss=2.16
# Epoch 3: 13.87s, train acc=0.56, train loss=1.98, validation acc=0.56, validation loss=1.97
# Epoch 4: 17.69s, train acc=0.64, train loss=1.67, validation acc=0.64, validation loss=1.66
# Epoch 5: 24.03s, train acc=0.71, train loss=1.36, validation acc=0.72, validation loss=1.35
# Epoch 6: 27.86s, train acc=0.75, train loss=1.11, validation acc=0.76, validation loss=1.10
# Epoch 7: 31.74s, train acc=0.78, train loss=0.93, validation acc=0.78, validation loss=0.92
# Epoch 8: 37.90s, train acc=0.81, train loss=0.80, validation acc=0.81, validation loss=0.79
# Epoch 9: 41.71s, train acc=0.83, train loss=0.71, validation acc=0.83, validation loss=0.70
# Epoch 10: 45.50s, train acc=0.84, train loss=0.64, validation acc=0.85, validation loss=0.63
# Epoch 11: 51.15s, train acc=0.85, train loss=0.58, validation acc=0.86, validation loss=0.57
# Epoch 12: 55.17s, train acc=0.86, train loss=0.54, validation acc=0.87, validation loss=0.53
# Epoch 13: 58.97s, train acc=0.87, train loss=0.51, validation acc=0.87, validation loss=0.50
# Epoch 14: 63.75s, train acc=0.87, train loss=0.48, validation acc=0.88, validation loss=0.47
# Epoch 15: 68.45s, train acc=0.88, train loss=0.46, validation acc=0.88, validation loss=0.45
# Epoch 16: 72.25s, train acc=0.88, train loss=0.44, validation acc=0.88, validation loss=0.43
# Epoch 17: 76.20s, train acc=0.88, train loss=0.43, validation acc=0.89, validation loss=0.42
# Epoch 18: 81.82s, train acc=0.89, train loss=0.41, validation acc=0.89, validation loss=0.40
# Epoch 19: 85.73s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.39
# Epoch 20: 89.56s, train acc=0.89, train loss=0.39, validation acc=0.89, validation loss=0.38
#
# Test acc=0.89, Test loss=0.38
#
# Testing combination: Activation=sigmoid, Optimizer=sgd, Learning Rate=0.001
# Epoch 1: 5.96s, train acc=0.19, train loss=2.30, validation acc=0.20, validation loss=2.30
# Epoch 2: 9.77s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 3: 13.51s, train acc=0.11, train loss=2.28, validation acc=0.11, validation loss=2.28
# Epoch 4: 19.92s, train acc=0.12, train loss=2.28, validation acc=0.12, validation loss=2.28
# Epoch 5: 23.79s, train acc=0.12, train loss=2.27, validation acc=0.13, validation loss=2.27
# Epoch 6: 27.59s, train acc=0.15, train loss=2.27, validation acc=0.16, validation loss=2.27
# Epoch 7: 33.79s, train acc=0.18, train loss=2.26, validation acc=0.18, validation loss=2.26
# Epoch 8: 37.61s, train acc=0.23, train loss=2.26, validation acc=0.24, validation loss=2.26
# Epoch 9: 41.44s, train acc=0.26, train loss=2.25, validation acc=0.26, validation loss=2.25
# Epoch 10: 47.29s, train acc=0.31, train loss=2.24, validation acc=0.31, validation loss=2.24
# Epoch 11: 51.19s, train acc=0.32, train loss=2.24, validation acc=0.32, validation loss=2.24
# Epoch 12: 55.08s, train acc=0.36, train loss=2.23, validation acc=0.37, validation loss=2.23
# Epoch 13: 60.03s, train acc=0.37, train loss=2.22, validation acc=0.38, validation loss=2.22
# Epoch 14: 64.67s, train acc=0.39, train loss=2.21, validation acc=0.40, validation loss=2.21
# Epoch 15: 68.50s, train acc=0.43, train loss=2.20, validation acc=0.43, validation loss=2.20
# Epoch 16: 72.37s, train acc=0.43, train loss=2.20, validation acc=0.44, validation loss=2.19
# Epoch 17: 78.10s, train acc=0.46, train loss=2.18, validation acc=0.47, validation loss=2.18
# Epoch 18: 81.90s, train acc=0.47, train loss=2.17, validation acc=0.47, validation loss=2.17
# Epoch 19: 85.74s, train acc=0.50, train loss=2.16, validation acc=0.50, validation loss=2.16
# Epoch 20: 91.92s, train acc=0.49, train loss=2.15, validation acc=0.49, validation loss=2.14
#
# Test acc=0.49, Test loss=2.14
#
# Testing combination: Activation=sigmoid, Optimizer=momentum, Learning Rate=0.01
# Epoch 1: 4.11s, train acc=0.28, train loss=2.25, validation acc=0.29, validation loss=2.25
# Epoch 2: 8.30s, train acc=0.35, train loss=2.17, validation acc=0.37, validation loss=2.17
# Epoch 3: 14.65s, train acc=0.54, train loss=1.98, validation acc=0.54, validation loss=1.98
# Epoch 4: 18.88s, train acc=0.60, train loss=1.66, validation acc=0.61, validation loss=1.65
# Epoch 5: 23.48s, train acc=0.65, train loss=1.33, validation acc=0.67, validation loss=1.32
# Epoch 6: 29.26s, train acc=0.72, train loss=1.10, validation acc=0.72, validation loss=1.09
# Epoch 7: 33.43s, train acc=0.75, train loss=0.95, validation acc=0.76, validation loss=0.94
# Epoch 8: 38.24s, train acc=0.78, train loss=0.84, validation acc=0.79, validation loss=0.83
# Epoch 9: 43.66s, train acc=0.81, train loss=0.76, validation acc=0.81, validation loss=0.74
# Epoch 10: 47.91s, train acc=0.82, train loss=0.69, validation acc=0.83, validation loss=0.68
# Epoch 11: 52.97s, train acc=0.83, train loss=0.63, validation acc=0.84, validation loss=0.62
# Epoch 12: 58.19s, train acc=0.85, train loss=0.59, validation acc=0.85, validation loss=0.58
# Epoch 13: 62.38s, train acc=0.85, train loss=0.56, validation acc=0.86, validation loss=0.54
# Epoch 14: 67.95s, train acc=0.86, train loss=0.53, validation acc=0.86, validation loss=0.51
# Epoch 15: 72.76s, train acc=0.87, train loss=0.50, validation acc=0.87, validation loss=0.49
# Epoch 16: 76.98s, train acc=0.87, train loss=0.48, validation acc=0.87, validation loss=0.47
# Epoch 17: 82.69s, train acc=0.88, train loss=0.46, validation acc=0.88, validation loss=0.45
# Epoch 18: 87.62s, train acc=0.88, train loss=0.44, validation acc=0.88, validation loss=0.43
# Epoch 19: 91.87s, train acc=0.88, train loss=0.43, validation acc=0.88, validation loss=0.42
# Epoch 20: 97.67s, train acc=0.89, train loss=0.42, validation acc=0.89, validation loss=0.41
#
# Test acc=0.89, Test loss=0.41
#
# Testing combination: Activation=sigmoid, Optimizer=momentum, Learning Rate=0.001
# Epoch 1: 4.31s, train acc=0.16, train loss=2.30, validation acc=0.16, validation loss=2.30
# Epoch 2: 8.48s, train acc=0.11, train loss=2.29, validation acc=0.11, validation loss=2.29
# Epoch 3: 14.63s, train acc=0.11, train loss=2.29, validation acc=0.12, validation loss=2.29
# Epoch 4: 18.99s, train acc=0.11, train loss=2.28, validation acc=0.12, validation loss=2.28
# Epoch 5: 23.23s, train acc=0.12, train loss=2.28, validation acc=0.12, validation loss=2.28
# Epoch 6: 29.48s, train acc=0.15, train loss=2.27, validation acc=0.15, validation loss=2.27
# Epoch 7: 33.69s, train acc=0.15, train loss=2.27, validation acc=0.14, validation loss=2.27
# Epoch 8: 37.87s, train acc=0.19, train loss=2.26, validation acc=0.20, validation loss=2.26
# Epoch 9: 44.59s, train acc=0.22, train loss=2.26, validation acc=0.23, validation loss=2.26
# Epoch 10: 48.82s, train acc=0.28, train loss=2.25, validation acc=0.29, validation loss=2.25
# Epoch 11: 53.10s, train acc=0.30, train loss=2.25, validation acc=0.31, validation loss=2.25
# Epoch 12: 59.69s, train acc=0.34, train loss=2.24, validation acc=0.35, validation loss=2.24
# Epoch 13: 63.88s, train acc=0.36, train loss=2.23, validation acc=0.37, validation loss=2.23
# Epoch 14: 68.06s, train acc=0.37, train loss=2.23, validation acc=0.39, validation loss=2.22
# Epoch 15: 74.41s, train acc=0.38, train loss=2.22, validation acc=0.39, validation loss=2.22
# Epoch 16: 78.67s, train acc=0.41, train loss=2.21, validation acc=0.43, validation loss=2.21
# Epoch 17: 83.33s, train acc=0.43, train loss=2.20, validation acc=0.44, validation loss=2.20
# Epoch 18: 89.17s, train acc=0.44, train loss=2.19, validation acc=0.45, validation loss=2.19
# Epoch 19: 93.37s, train acc=0.44, train loss=2.18, validation acc=0.45, validation loss=2.18
# Epoch 20: 98.17s, train acc=0.46, train loss=2.17, validation acc=0.47, validation loss=2.17
#
# Test acc=0.47, Test loss=2.17
#
# Testing combination: Activation=sigmoid, Optimizer=adam, Learning Rate=0.01
# Epoch 1: 6.56s, train acc=0.96, train loss=0.12, validation acc=0.96, validation loss=0.14
# Epoch 2: 11.95s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.12
# Epoch 3: 19.80s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.11
# Epoch 4: 25.09s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.11
# Epoch 5: 32.87s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.11
# Epoch 6: 38.28s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.11
# Epoch 7: 45.39s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.11
# Epoch 8: 50.86s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.11
# Epoch 9: 56.08s, train acc=0.98, train loss=0.05, validation acc=0.97, validation loss=0.12
# Epoch 10: 63.72s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.12
# Epoch 11: 69.04s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 12: 76.99s, train acc=0.99, train loss=0.03, validation acc=0.98, validation loss=0.10
# Epoch 13: 82.18s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.10
# Epoch 14: 89.80s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.12
# Epoch 15: 95.03s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 16: 101.18s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.11
# Epoch 17: 107.47s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.12
# Epoch 18: 112.87s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.12
# Epoch 19: 120.61s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.13
# Epoch 20: 126.00s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.13
#
# Test acc=0.97, Test loss=0.13
#
# Testing combination: Activation=sigmoid, Optimizer=adam, Learning Rate=0.001
# Epoch 1: 7.79s, train acc=0.93, train loss=0.26, validation acc=0.93, validation loss=0.26
# Epoch 2: 13.04s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.18
# Epoch 3: 20.63s, train acc=0.96, train loss=0.13, validation acc=0.96, validation loss=0.14
# Epoch 4: 25.88s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.12
# Epoch 5: 31.47s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.10
# Epoch 6: 38.50s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.09
# Epoch 7: 43.79s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.09
# Epoch 8: 51.54s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.08
# Epoch 9: 56.88s, train acc=0.99, train loss=0.03, validation acc=0.98, validation loss=0.08
# Epoch 10: 64.53s, train acc=0.99, train loss=0.03, validation acc=0.98, validation loss=0.08
# Epoch 11: 69.94s, train acc=0.99, train loss=0.03, validation acc=0.98, validation loss=0.08
# Epoch 12: 76.46s, train acc=0.99, train loss=0.02, validation acc=0.98, validation loss=0.08
# Epoch 13: 82.50s, train acc=1.00, train loss=0.02, validation acc=0.98, validation loss=0.08
# Epoch 14: 87.79s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.08
# Epoch 15: 95.45s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.08
# Epoch 16: 100.77s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.08
# Epoch 17: 108.56s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.09
# Epoch 18: 113.89s, train acc=1.00, train loss=0.00, validation acc=0.98, validation loss=0.08
# Epoch 19: 121.58s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.09
# Epoch 20: 127.06s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.09
#
# Test acc=0.98, Test loss=0.09
#
# Testing combination: Activation=tanh, Optimizer=sgd, Learning Rate=0.01
# Epoch 1: 6.11s, train acc=0.87, train loss=0.51, validation acc=0.88, validation loss=0.49
# Epoch 2: 12.52s, train acc=0.90, train loss=0.38, validation acc=0.90, validation loss=0.37
# Epoch 3: 18.11s, train acc=0.91, train loss=0.33, validation acc=0.91, validation loss=0.32
# Epoch 4: 25.94s, train acc=0.91, train loss=0.31, validation acc=0.92, validation loss=0.30
# Epoch 5: 31.70s, train acc=0.92, train loss=0.29, validation acc=0.92, validation loss=0.28
# Epoch 6: 39.61s, train acc=0.92, train loss=0.27, validation acc=0.93, validation loss=0.26
# Epoch 7: 45.14s, train acc=0.93, train loss=0.26, validation acc=0.93, validation loss=0.25
# Epoch 8: 53.07s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.24
# Epoch 9: 58.69s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.23
# Epoch 10: 66.34s, train acc=0.94, train loss=0.22, validation acc=0.94, validation loss=0.22
# Epoch 11: 71.84s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.21
# Epoch 12: 78.02s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.20
# Epoch 13: 84.32s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.20
# Epoch 14: 89.86s, train acc=0.95, train loss=0.19, validation acc=0.95, validation loss=0.19
# Epoch 15: 97.65s, train acc=0.95, train loss=0.18, validation acc=0.95, validation loss=0.18
# Epoch 16: 103.16s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.18
# Epoch 17: 111.10s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.17
# Epoch 18: 116.77s, train acc=0.95, train loss=0.16, validation acc=0.95, validation loss=0.17
# Epoch 19: 124.76s, train acc=0.96, train loss=0.16, validation acc=0.95, validation loss=0.16
# Epoch 20: 130.30s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.16
#
# Test acc=0.95, Test loss=0.16
#
# Testing combination: Activation=tanh, Optimizer=sgd, Learning Rate=0.001
# Epoch 1: 7.91s, train acc=0.68, train loss=1.56, validation acc=0.68, validation loss=1.56
# Epoch 2: 13.52s, train acc=0.77, train loss=1.18, validation acc=0.78, validation loss=1.17
# Epoch 3: 20.54s, train acc=0.81, train loss=0.96, validation acc=0.82, validation loss=0.94
# Epoch 4: 26.26s, train acc=0.83, train loss=0.81, validation acc=0.84, validation loss=0.80
# Epoch 5: 32.06s, train acc=0.85, train loss=0.72, validation acc=0.85, validation loss=0.70
# Epoch 6: 39.06s, train acc=0.86, train loss=0.65, validation acc=0.86, validation loss=0.63
# Epoch 7: 44.65s, train acc=0.86, train loss=0.60, validation acc=0.87, validation loss=0.58
# Epoch 8: 52.63s, train acc=0.87, train loss=0.56, validation acc=0.88, validation loss=0.54
# Epoch 9: 58.17s, train acc=0.87, train loss=0.53, validation acc=0.88, validation loss=0.51
# Epoch 10: 66.22s, train acc=0.88, train loss=0.50, validation acc=0.88, validation loss=0.48
# Epoch 11: 71.73s, train acc=0.88, train loss=0.48, validation acc=0.89, validation loss=0.46
# Epoch 12: 79.54s, train acc=0.88, train loss=0.46, validation acc=0.89, validation loss=0.45
# Epoch 13: 85.06s, train acc=0.89, train loss=0.45, validation acc=0.89, validation loss=0.43
# Epoch 14: 92.34s, train acc=0.89, train loss=0.43, validation acc=0.89, validation loss=0.42
# Epoch 15: 97.87s, train acc=0.89, train loss=0.42, validation acc=0.90, validation loss=0.41
# Epoch 16: 103.94s, train acc=0.89, train loss=0.41, validation acc=0.90, validation loss=0.40
# Epoch 17: 110.71s, train acc=0.89, train loss=0.40, validation acc=0.90, validation loss=0.39
# Epoch 18: 116.27s, train acc=0.90, train loss=0.39, validation acc=0.90, validation loss=0.38
# Epoch 19: 124.19s, train acc=0.90, train loss=0.38, validation acc=0.90, validation loss=0.37
# Epoch 20: 129.74s, train acc=0.90, train loss=0.38, validation acc=0.90, validation loss=0.36
#
# Test acc=0.90, Test loss=0.36
#
# Testing combination: Activation=tanh, Optimizer=momentum, Learning Rate=0.01
# Epoch 1: 8.37s, train acc=0.87, train loss=0.50, validation acc=0.88, validation loss=0.49
# Epoch 2: 14.28s, train acc=0.90, train loss=0.38, validation acc=0.90, validation loss=0.37
# Epoch 3: 22.58s, train acc=0.91, train loss=0.33, validation acc=0.91, validation loss=0.32
# Epoch 4: 28.61s, train acc=0.91, train loss=0.30, validation acc=0.92, validation loss=0.29
# Epoch 5: 37.15s, train acc=0.92, train loss=0.28, validation acc=0.92, validation loss=0.28
# Epoch 6: 43.15s, train acc=0.92, train loss=0.27, validation acc=0.92, validation loss=0.26
# Epoch 7: 51.47s, train acc=0.93, train loss=0.25, validation acc=0.93, validation loss=0.25
# Epoch 8: 57.43s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.24
# Epoch 9: 65.83s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.23
# Epoch 10: 71.81s, train acc=0.94, train loss=0.22, validation acc=0.94, validation loss=0.22
# Epoch 11: 80.38s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.21
# Epoch 12: 86.36s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.20
# Epoch 13: 94.83s, train acc=0.94, train loss=0.19, validation acc=0.94, validation loss=0.20
# Epoch 14: 100.94s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.19
# Epoch 15: 109.10s, train acc=0.95, train loss=0.18, validation acc=0.95, validation loss=0.18
# Epoch 16: 115.04s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.18
# Epoch 17: 123.38s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.17
# Epoch 18: 129.39s, train acc=0.95, train loss=0.16, validation acc=0.95, validation loss=0.16
# Epoch 19: 137.74s, train acc=0.96, train loss=0.16, validation acc=0.95, validation loss=0.16
# Epoch 20: 143.65s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.16
#
# Test acc=0.95, Test loss=0.16
#
# Testing combination: Activation=tanh, Optimizer=momentum, Learning Rate=0.001
# Epoch 1: 8.14s, train acc=0.69, train loss=1.61, validation acc=0.69, validation loss=1.60
# Epoch 2: 14.17s, train acc=0.77, train loss=1.20, validation acc=0.77, validation loss=1.18
# Epoch 3: 22.40s, train acc=0.80, train loss=0.96, validation acc=0.81, validation loss=0.94
# Epoch 4: 28.39s, train acc=0.83, train loss=0.81, validation acc=0.84, validation loss=0.79
# Epoch 5: 36.72s, train acc=0.84, train loss=0.71, validation acc=0.85, validation loss=0.70
# Epoch 6: 42.82s, train acc=0.86, train loss=0.64, validation acc=0.86, validation loss=0.63
# Epoch 7: 51.01s, train acc=0.86, train loss=0.59, validation acc=0.87, validation loss=0.57
# Epoch 8: 57.02s, train acc=0.87, train loss=0.55, validation acc=0.88, validation loss=0.54
# Epoch 9: 65.30s, train acc=0.88, train loss=0.52, validation acc=0.88, validation loss=0.50
# Epoch 10: 71.27s, train acc=0.88, train loss=0.49, validation acc=0.89, validation loss=0.48
# Epoch 11: 79.54s, train acc=0.88, train loss=0.47, validation acc=0.89, validation loss=0.46
# Epoch 12: 85.62s, train acc=0.88, train loss=0.46, validation acc=0.89, validation loss=0.44
# Epoch 13: 93.89s, train acc=0.89, train loss=0.44, validation acc=0.89, validation loss=0.43
# Epoch 14: 99.86s, train acc=0.89, train loss=0.43, validation acc=0.90, validation loss=0.41
# Epoch 15: 107.98s, train acc=0.89, train loss=0.41, validation acc=0.90, validation loss=0.40
# Epoch 16: 113.95s, train acc=0.89, train loss=0.40, validation acc=0.90, validation loss=0.39
# Epoch 17: 122.02s, train acc=0.90, train loss=0.40, validation acc=0.90, validation loss=0.38
# Epoch 18: 127.99s, train acc=0.90, train loss=0.39, validation acc=0.90, validation loss=0.37
# Epoch 19: 136.17s, train acc=0.90, train loss=0.38, validation acc=0.90, validation loss=0.37
# Epoch 20: 142.15s, train acc=0.90, train loss=0.37, validation acc=0.90, validation loss=0.36
#
# Test acc=0.90, Test loss=0.36
#
# Testing combination: Activation=tanh, Optimizer=adam, Learning Rate=0.01
# Epoch 1: 9.15s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.19
# Epoch 2: 17.60s, train acc=0.95, train loss=0.16, validation acc=0.95, validation loss=0.18
# Epoch 3: 25.13s, train acc=0.95, train loss=0.17, validation acc=0.94, validation loss=0.18
# Epoch 4: 34.55s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.20
# Epoch 5: 41.79s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.19
# Epoch 6: 51.15s, train acc=0.95, train loss=0.18, validation acc=0.94, validation loss=0.19
# Epoch 7: 59.04s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.19
# Epoch 8: 67.02s, train acc=0.95, train loss=0.15, validation acc=0.95, validation loss=0.18
# Epoch 9: 76.33s, train acc=0.95, train loss=0.16, validation acc=0.95, validation loss=0.18
# Epoch 10: 83.52s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.17
# Epoch 11: 92.87s, train acc=0.95, train loss=0.15, validation acc=0.95, validation loss=0.18
# Epoch 12: 100.61s, train acc=0.95, train loss=0.15, validation acc=0.94, validation loss=0.19
# Epoch 13: 108.76s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.19
# Epoch 14: 118.64s, train acc=0.95, train loss=0.16, validation acc=0.94, validation loss=0.19
# Epoch 15: 125.89s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.17
# Epoch 16: 135.47s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.17
# Epoch 17: 143.22s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.17
# Epoch 18: 151.79s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.17
# Epoch 19: 161.56s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.17
# Epoch 20: 169.03s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.17
#
# Test acc=0.95, Test loss=0.17
#
# Testing combination: Activation=tanh, Optimizer=adam, Learning Rate=0.001
# Epoch 1: 9.58s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.17
# Epoch 2: 17.27s, train acc=0.97, train loss=0.11, validation acc=0.96, validation loss=0.13
# Epoch 3: 25.40s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.10
# Epoch 4: 34.59s, train acc=0.98, train loss=0.05, validation acc=0.97, validation loss=0.09
# Epoch 5: 41.64s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.08
# Epoch 6: 50.77s, train acc=0.99, train loss=0.03, validation acc=0.98, validation loss=0.08
# Epoch 7: 58.03s, train acc=0.99, train loss=0.03, validation acc=0.98, validation loss=0.08
# Epoch 8: 66.76s, train acc=0.99, train loss=0.02, validation acc=0.98, validation loss=0.08
# Epoch 9: 75.68s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.08
# Epoch 10: 82.79s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.07
# Epoch 11: 92.41s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.08
# Epoch 12: 99.51s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.08
# Epoch 13: 109.00s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.08
# Epoch 14: 117.12s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.10
# Epoch 15: 124.46s, train acc=1.00, train loss=0.00, validation acc=0.98, validation loss=0.08
# Epoch 16: 133.72s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.10
# Epoch 17: 140.75s, train acc=1.00, train loss=0.00, validation acc=0.98, validation loss=0.09
# Epoch 18: 150.21s, train acc=1.00, train loss=0.00, validation acc=0.98, validation loss=0.10
# Epoch 19: 157.94s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.10
# Epoch 20: 165.99s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.11
#
# Test acc=0.98, Test loss=0.11
#
# Testing combination: Activation=leaky_relu, Optimizer=sgd, Learning Rate=0.01
# Epoch 1: 3.33s, train acc=0.87, train loss=0.48, validation acc=0.88, validation loss=0.46
# Epoch 2: 9.11s, train acc=0.90, train loss=0.35, validation acc=0.91, validation loss=0.34
# Epoch 3: 12.46s, train acc=0.91, train loss=0.31, validation acc=0.91, validation loss=0.30
# Epoch 4: 15.81s, train acc=0.92, train loss=0.28, validation acc=0.92, validation loss=0.27
# Epoch 5: 19.80s, train acc=0.93, train loss=0.26, validation acc=0.93, validation loss=0.25
# Epoch 6: 24.58s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.23
# Epoch 7: 27.93s, train acc=0.94, train loss=0.22, validation acc=0.94, validation loss=0.22
# Epoch 8: 31.26s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.21
# Epoch 9: 37.05s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.19
# Epoch 10: 40.42s, train acc=0.95, train loss=0.18, validation acc=0.95, validation loss=0.19
# Epoch 11: 43.78s, train acc=0.95, train loss=0.18, validation acc=0.95, validation loss=0.18
# Epoch 12: 47.21s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.17
# Epoch 13: 52.73s, train acc=0.95, train loss=0.16, validation acc=0.95, validation loss=0.16
# Epoch 14: 56.09s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.16
# Epoch 15: 59.48s, train acc=0.96, train loss=0.14, validation acc=0.95, validation loss=0.15
# Epoch 16: 64.24s, train acc=0.96, train loss=0.14, validation acc=0.96, validation loss=0.15
# Epoch 17: 68.26s, train acc=0.96, train loss=0.13, validation acc=0.96, validation loss=0.14
# Epoch 18: 71.61s, train acc=0.96, train loss=0.13, validation acc=0.96, validation loss=0.14
# Epoch 19: 74.98s, train acc=0.97, train loss=0.12, validation acc=0.96, validation loss=0.13
# Epoch 20: 80.91s, train acc=0.97, train loss=0.12, validation acc=0.96, validation loss=0.13
#
# Test acc=0.96, Test loss=0.13
#
# Testing combination: Activation=leaky_relu, Optimizer=sgd, Learning Rate=0.001
# Epoch 1: 3.39s, train acc=0.47, train loss=2.10, validation acc=0.48, validation loss=2.10
# Epoch 2: 6.72s, train acc=0.64, train loss=1.77, validation acc=0.64, validation loss=1.76
# Epoch 3: 10.49s, train acc=0.73, train loss=1.37, validation acc=0.74, validation loss=1.36
# Epoch 4: 15.42s, train acc=0.77, train loss=1.05, validation acc=0.78, validation loss=1.03
# Epoch 5: 18.76s, train acc=0.81, train loss=0.84, validation acc=0.81, validation loss=0.82
# Epoch 6: 22.07s, train acc=0.83, train loss=0.72, validation acc=0.83, validation loss=0.70
# Epoch 7: 26.87s, train acc=0.84, train loss=0.63, validation acc=0.85, validation loss=0.61
# Epoch 8: 30.72s, train acc=0.85, train loss=0.57, validation acc=0.86, validation loss=0.55
# Epoch 9: 34.01s, train acc=0.86, train loss=0.53, validation acc=0.87, validation loss=0.51
# Epoch 10: 37.32s, train acc=0.87, train loss=0.49, validation acc=0.88, validation loss=0.47
# Epoch 11: 43.07s, train acc=0.88, train loss=0.47, validation acc=0.88, validation loss=0.45
# Epoch 12: 46.38s, train acc=0.88, train loss=0.44, validation acc=0.89, validation loss=0.43
# Epoch 13: 49.65s, train acc=0.88, train loss=0.43, validation acc=0.89, validation loss=0.41
# Epoch 14: 53.08s, train acc=0.89, train loss=0.41, validation acc=0.89, validation loss=0.40
# Epoch 15: 58.52s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.38
# Epoch 16: 61.83s, train acc=0.89, train loss=0.39, validation acc=0.90, validation loss=0.37
# Epoch 17: 65.15s, train acc=0.89, train loss=0.38, validation acc=0.90, validation loss=0.36
# Epoch 18: 69.63s, train acc=0.90, train loss=0.37, validation acc=0.90, validation loss=0.36
# Epoch 19: 73.72s, train acc=0.90, train loss=0.36, validation acc=0.90, validation loss=0.35
# Epoch 20: 77.08s, train acc=0.90, train loss=0.36, validation acc=0.90, validation loss=0.34
#
# Test acc=0.90, Test loss=0.34
#
# Testing combination: Activation=leaky_relu, Optimizer=momentum, Learning Rate=0.01
# Epoch 1: 3.68s, train acc=0.87, train loss=0.50, validation acc=0.88, validation loss=0.48
# Epoch 2: 9.93s, train acc=0.90, train loss=0.36, validation acc=0.90, validation loss=0.34
# Epoch 3: 13.63s, train acc=0.91, train loss=0.31, validation acc=0.91, validation loss=0.30
# Epoch 4: 17.36s, train acc=0.92, train loss=0.28, validation acc=0.92, validation loss=0.28
# Epoch 5: 23.55s, train acc=0.93, train loss=0.26, validation acc=0.93, validation loss=0.25
# Epoch 6: 27.26s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.24
# Epoch 7: 31.03s, train acc=0.94, train loss=0.22, validation acc=0.94, validation loss=0.22
# Epoch 8: 36.11s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.21
# Epoch 9: 40.43s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.19
# Epoch 10: 44.11s, train acc=0.95, train loss=0.18, validation acc=0.95, validation loss=0.18
# Epoch 11: 48.10s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.18
# Epoch 12: 53.53s, train acc=0.95, train loss=0.16, validation acc=0.95, validation loss=0.17
# Epoch 13: 57.28s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.16
# Epoch 14: 61.06s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.15
# Epoch 15: 67.15s, train acc=0.96, train loss=0.14, validation acc=0.96, validation loss=0.15
# Epoch 16: 70.93s, train acc=0.96, train loss=0.13, validation acc=0.96, validation loss=0.14
# Epoch 17: 74.63s, train acc=0.96, train loss=0.13, validation acc=0.96, validation loss=0.14
# Epoch 18: 80.92s, train acc=0.97, train loss=0.12, validation acc=0.96, validation loss=0.13
# Epoch 19: 84.64s, train acc=0.97, train loss=0.12, validation acc=0.96, validation loss=0.13
# Epoch 20: 88.39s, train acc=0.97, train loss=0.11, validation acc=0.96, validation loss=0.12
#
# Test acc=0.96, Test loss=0.12
#
# Testing combination: Activation=leaky_relu, Optimizer=momentum, Learning Rate=0.001
# Epoch 1: 6.09s, train acc=0.47, train loss=2.08, validation acc=0.48, validation loss=2.07
# Epoch 2: 9.90s, train acc=0.67, train loss=1.73, validation acc=0.68, validation loss=1.71
# Epoch 3: 13.76s, train acc=0.74, train loss=1.32, validation acc=0.75, validation loss=1.29
# Epoch 4: 18.99s, train acc=0.78, train loss=1.01, validation acc=0.79, validation loss=0.98
# Epoch 5: 23.33s, train acc=0.81, train loss=0.82, validation acc=0.82, validation loss=0.79
# Epoch 6: 27.04s, train acc=0.83, train loss=0.70, validation acc=0.84, validation loss=0.67
# Epoch 7: 30.91s, train acc=0.85, train loss=0.62, validation acc=0.86, validation loss=0.60
# Epoch 8: 36.59s, train acc=0.86, train loss=0.56, validation acc=0.87, validation loss=0.54
# Epoch 9: 40.29s, train acc=0.87, train loss=0.52, validation acc=0.88, validation loss=0.50
# Epoch 10: 43.95s, train acc=0.87, train loss=0.49, validation acc=0.88, validation loss=0.47
# Epoch 11: 50.17s, train acc=0.88, train loss=0.46, validation acc=0.89, validation loss=0.44
# Epoch 12: 53.83s, train acc=0.88, train loss=0.44, validation acc=0.89, validation loss=0.42
# Epoch 13: 57.57s, train acc=0.89, train loss=0.42, validation acc=0.89, validation loss=0.40
# Epoch 14: 63.43s, train acc=0.89, train loss=0.41, validation acc=0.90, validation loss=0.39
# Epoch 15: 67.09s, train acc=0.89, train loss=0.40, validation acc=0.90, validation loss=0.38
# Epoch 16: 70.81s, train acc=0.89, train loss=0.38, validation acc=0.90, validation loss=0.37
# Epoch 17: 75.64s, train acc=0.90, train loss=0.38, validation acc=0.90, validation loss=0.36
# Epoch 18: 80.25s, train acc=0.90, train loss=0.37, validation acc=0.90, validation loss=0.35
# Epoch 19: 83.90s, train acc=0.90, train loss=0.36, validation acc=0.91, validation loss=0.34
# Epoch 20: 87.56s, train acc=0.90, train loss=0.35, validation acc=0.91, validation loss=0.34
#
# Test acc=0.91, Test loss=0.34
#
# Testing combination: Activation=leaky_relu, Optimizer=adam, Learning Rate=0.01
# Epoch 1: 7.08s, train acc=0.95, train loss=0.15, validation acc=0.95, validation loss=0.18
# Epoch 2: 11.82s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.14
# Epoch 3: 18.61s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.11
# Epoch 4: 23.42s, train acc=0.97, train loss=0.10, validation acc=0.96, validation loss=0.14
# Epoch 5: 28.19s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.14
# Epoch 6: 35.36s, train acc=0.98, train loss=0.09, validation acc=0.96, validation loss=0.17
# Epoch 7: 40.08s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.14
# Epoch 8: 46.51s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.15
# Epoch 9: 51.63s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.16
# Epoch 10: 56.30s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.13
# Epoch 11: 63.50s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.14
# Epoch 12: 68.21s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.13
# Epoch 13: 73.50s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.12
# Epoch 14: 79.74s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.15
# Epoch 15: 84.51s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.13
# Epoch 16: 91.59s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.14
# Epoch 17: 96.43s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.13
# Epoch 18: 101.18s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.15
# Epoch 19: 108.06s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.16
# Epoch 20: 112.75s, train acc=0.99, train loss=0.03, validation acc=0.98, validation loss=0.12
#
# Test acc=0.98, Test loss=0.12
#
# Testing combination: Activation=leaky_relu, Optimizer=adam, Learning Rate=0.001
# Epoch 1: 6.87s, train acc=0.96, train loss=0.14, validation acc=0.96, validation loss=0.15
# Epoch 2: 11.72s, train acc=0.97, train loss=0.09, validation acc=0.97, validation loss=0.11
# Epoch 3: 16.47s, train acc=0.98, train loss=0.05, validation acc=0.97, validation loss=0.09
# Epoch 4: 23.49s, train acc=0.98, train loss=0.05, validation acc=0.97, validation loss=0.10
# Epoch 5: 28.34s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.08
# Epoch 6: 35.30s, train acc=0.99, train loss=0.03, validation acc=0.98, validation loss=0.07
# Epoch 7: 40.09s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.09
# Epoch 8: 45.20s, train acc=0.99, train loss=0.02, validation acc=0.98, validation loss=0.09
# Epoch 9: 51.86s, train acc=0.99, train loss=0.02, validation acc=0.98, validation loss=0.09
# Epoch 10: 56.66s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.08
# Epoch 11: 63.87s, train acc=0.99, train loss=0.02, validation acc=0.98, validation loss=0.09
# Epoch 12: 68.65s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.09
# Epoch 13: 73.81s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.10
# Epoch 14: 80.21s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.10
# Epoch 15: 85.06s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.10
# Epoch 16: 92.41s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.11
# Epoch 17: 97.39s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.10
# Epoch 18: 102.74s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.10
# Epoch 19: 108.86s, train acc=1.00, train loss=0.00, validation acc=0.98, validation loss=0.10
# Epoch 20: 113.77s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.12
#
# Test acc=0.98, Test loss=0.12
#
# Testing combination: Activation=selu, Optimizer=sgd, Learning Rate=0.01
# Epoch 1: 6.51s, train acc=0.89, train loss=0.38, validation acc=0.90, validation loss=0.37
# Epoch 2: 10.55s, train acc=0.91, train loss=0.32, validation acc=0.91, validation loss=0.31
# Epoch 3: 14.62s, train acc=0.91, train loss=0.30, validation acc=0.92, validation loss=0.29
# Epoch 4: 21.21s, train acc=0.92, train loss=0.28, validation acc=0.92, validation loss=0.27
# Epoch 5: 25.27s, train acc=0.92, train loss=0.27, validation acc=0.93, validation loss=0.26
# Epoch 6: 29.35s, train acc=0.93, train loss=0.25, validation acc=0.93, validation loss=0.25
# Epoch 7: 35.90s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.24
# Epoch 8: 39.90s, train acc=0.94, train loss=0.23, validation acc=0.93, validation loss=0.23
# Epoch 9: 43.93s, train acc=0.94, train loss=0.22, validation acc=0.93, validation loss=0.23
# ...
# Epoch 18: 95.42s, train acc=0.91, train loss=0.33, validation acc=0.91, validation loss=0.31
# Epoch 19: 100.03s, train acc=0.91, train loss=0.32, validation acc=0.91, validation loss=0.31
# Epoch 20: 104.45s, train acc=0.91, train loss=0.32, validation acc=0.91, validation loss=0.31
#
# Test acc=0.91, Test loss=0.31
#
# Testing combination: Activation=selu, Optimizer=adam, Learning Rate=0.01
# Epoch 1: 8.09s, train acc=0.95, train loss=0.19, validation acc=0.95, validation loss=0.21
# Epoch 2: 13.71s, train acc=0.96, train loss=0.13, validation acc=0.96, validation loss=0.16
# Epoch 3: 21.86s, train acc=0.97, train loss=0.12, validation acc=0.96, validation loss=0.17
# Epoch 4: 27.35s, train acc=0.97, train loss=0.11, validation acc=0.96, validation loss=0.18
# Epoch 5: 35.33s, train acc=0.96, train loss=0.15, validation acc=0.95, validation loss=0.20
# Epoch 6: 41.06s, train acc=0.98, train loss=0.10, validation acc=0.96, validation loss=0.19
# Epoch 7: 48.35s, train acc=0.98, train loss=0.09, validation acc=0.97, validation loss=0.19
# Epoch 8: 53.98s, train acc=0.97, train loss=0.11, validation acc=0.96, validation loss=0.19
# Epoch 9: 59.69s, train acc=0.97, train loss=0.12, validation acc=0.96, validation loss=0.24
# Epoch 10: 66.97s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.18
# Epoch 11: 72.63s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.18
# Epoch 12: 80.80s, train acc=0.97, train loss=0.12, validation acc=0.96, validation loss=0.26
# Epoch 13: 86.39s, train acc=0.98, train loss=0.09, validation acc=0.97, validation loss=0.23
# Epoch 14: 94.48s, train acc=0.98, train loss=0.09, validation acc=0.97, validation loss=0.22
# Epoch 15: 99.96s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.21
# Epoch 16: 107.76s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.21
# Epoch 17: 113.34s, train acc=0.98, train loss=0.11, validation acc=0.96, validation loss=0.26
# Epoch 18: 120.70s, train acc=0.99, train loss=0.07, validation acc=0.97, validation loss=0.23
# Epoch 19: 126.41s, train acc=0.97, train loss=0.13, validation acc=0.95, validation loss=0.30
# Epoch 20: 132.55s, train acc=0.98, train loss=0.10, validation acc=0.96, validation loss=0.26
#
# Test acc=0.96, Test loss=0.26
#
# Testing combination: Activation=selu, Optimizer=adam, Learning Rate=0.001
# Epoch 1: 6.79s, train acc=0.94, train loss=0.19, validation acc=0.94, validation loss=0.19
# Epoch 2: 12.38s, train acc=0.96, train loss=0.12, validation acc=0.96, validation loss=0.14
# Epoch 3: 20.31s, train acc=0.97, train loss=0.08, validation acc=0.97, validation loss=0.10
# Epoch 4: 25.85s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.10
# Epoch 5: 33.87s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.10
# Epoch 6: 39.57s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.09
# Epoch 7: 47.58s, train acc=0.99, train loss=0.03, validation acc=0.98, validation loss=0.08
# Epoch 8: 53.24s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.09
# Epoch 9: 61.30s, train acc=0.99, train loss=0.03, validation acc=0.98, validation loss=0.09
# Epoch 10: 66.96s, train acc=0.99, train loss=0.02, validation acc=0.98, validation loss=0.09
# Epoch 11: 74.88s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.10
# Epoch 12: 81.87s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.08
# Epoch 13: 92.41s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.09
# Epoch 14: 100.02s, train acc=0.99, train loss=0.02, validation acc=0.97, validation loss=0.10
# Epoch 15: 110.15s, train acc=0.99, train loss=0.01, validation acc=0.98, validation loss=0.10
# Epoch 16: 118.79s, train acc=0.99, train loss=0.01, validation acc=0.98, validation loss=0.11
# Epoch 17: 127.88s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.10
# Epoch 18: 137.78s, train acc=0.99, train loss=0.02, validation acc=0.98, validation loss=0.10
# Epoch 19: 145.34s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.10
# Epoch 20: 155.66s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.11
#
# Test acc=0.98, Test loss=0.11
#
# Testing combination: Activation=elu, Optimizer=sgd, Learning Rate=0.01
# Epoch 1: 5.60s, train acc=0.88, train loss=0.44, validation acc=0.89, validation loss=0.42
# Epoch 2: 12.42s, train acc=0.90, train loss=0.35, validation acc=0.91, validation loss=0.34
# Epoch 3: 18.38s, train acc=0.91, train loss=0.32, validation acc=0.92, validation loss=0.30
# Epoch 4: 23.86s, train acc=0.92, train loss=0.30, validation acc=0.92, validation loss=0.29
# Epoch 5: 31.51s, train acc=0.92, train loss=0.28, validation acc=0.92, validation loss=0.28
# Epoch 6: 36.84s, train acc=0.92, train loss=0.27, validation acc=0.93, validation loss=0.26
# Epoch 7: 43.51s, train acc=0.93, train loss=0.26, validation acc=0.93, validation loss=0.25
# Epoch 8: 49.52s, train acc=0.93, train loss=0.25, validation acc=0.93, validation loss=0.24
# Epoch 9: 54.92s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.24
# Epoch 10: 62.90s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.23
# Epoch 11: 68.21s, train acc=0.94, train loss=0.22, validation acc=0.94, validation loss=0.22
# Epoch 12: 74.31s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.21
# Epoch 13: 80.92s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.20
# Epoch 14: 86.43s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.20
# Epoch 15: 94.52s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.19
# Epoch 16: 99.95s, train acc=0.95, train loss=0.18, validation acc=0.95, validation loss=0.18
# Epoch 17: 106.53s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.18
# Epoch 18: 112.72s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.17
# Epoch 19: 117.87s, train acc=0.95, train loss=0.16, validation acc=0.95, validation loss=0.17
# Epoch 20: 124.46s, train acc=0.96, train loss=0.16, validation acc=0.95, validation loss=0.16
#
# Test acc=0.95, Test loss=0.16
#
# Testing combination: Activation=elu, Optimizer=sgd, Learning Rate=0.001
# Epoch 1: 4.03s, train acc=0.69, train loss=1.61, validation acc=0.69, validation loss=1.60
# Epoch 2: 8.03s, train acc=0.77, train loss=1.13, validation acc=0.77, validation loss=1.11
# Epoch 3: 14.49s, train acc=0.80, train loss=0.87, validation acc=0.81, validation loss=0.85
# Epoch 4: 18.50s, train acc=0.83, train loss=0.72, validation acc=0.83, validation loss=0.70
# Epoch 5: 22.50s, train acc=0.84, train loss=0.63, validation acc=0.85, validation loss=0.61
# Epoch 6: 28.92s, train acc=0.85, train loss=0.57, validation acc=0.86, validation loss=0.55
# Epoch 7: 32.93s, train acc=0.86, train loss=0.52, validation acc=0.87, validation loss=0.50
# Epoch 8: 36.87s, train acc=0.87, train loss=0.49, validation acc=0.88, validation loss=0.47
# Epoch 9: 43.13s, train acc=0.88, train loss=0.46, validation acc=0.88, validation loss=0.44
# Epoch 10: 47.08s, train acc=0.88, train loss=0.44, validation acc=0.89, validation loss=0.42
# Epoch 11: 51.05s, train acc=0.89, train loss=0.42, validation acc=0.89, validation loss=0.41
# Epoch 12: 57.65s, train acc=0.89, train loss=0.41, validation acc=0.89, validation loss=0.39
# Epoch 13: 61.60s, train acc=0.89, train loss=0.40, validation acc=0.90, validation loss=0.38
# Epoch 14: 65.58s, train acc=0.89, train loss=0.39, validation acc=0.90, validation loss=0.37
# Epoch 15: 71.98s, train acc=0.89, train loss=0.38, validation acc=0.90, validation loss=0.36
# Epoch 16: 75.94s, train acc=0.90, train loss=0.37, validation acc=0.90, validation loss=0.35
# Epoch 17: 79.93s, train acc=0.90, train loss=0.36, validation acc=0.90, validation loss=0.35
# Epoch 18: 86.43s, train acc=0.90, train loss=0.36, validation acc=0.90, validation loss=0.34
# Epoch 19: 90.38s, train acc=0.90, train loss=0.35, validation acc=0.90, validation loss=0.34
# Epoch 20: 94.35s, train acc=0.90, train loss=0.35, validation acc=0.90, validation loss=0.33
#
# Test acc=0.90, Test loss=0.33
#
# Testing combination: Activation=elu, Optimizer=momentum, Learning Rate=0.01
# Epoch 1: 6.85s, train acc=0.88, train loss=0.45, validation acc=0.89, validation loss=0.43
# Epoch 2: 11.23s, train acc=0.90, train loss=0.35, validation acc=0.91, validation loss=0.34
# Epoch 3: 15.82s, train acc=0.91, train loss=0.32, validation acc=0.91, validation loss=0.31
# Epoch 4: 21.54s, train acc=0.91, train loss=0.30, validation acc=0.92, validation loss=0.29
# Epoch 5: 25.94s, train acc=0.92, train loss=0.28, validation acc=0.92, validation loss=0.28
# Epoch 6: 31.76s, train acc=0.92, train loss=0.27, validation acc=0.92, validation loss=0.27
# Epoch 7: 36.57s, train acc=0.92, train loss=0.26, validation acc=0.93, validation loss=0.26
# Epoch 8: 40.95s, train acc=0.93, train loss=0.25, validation acc=0.93, validation loss=0.25
# Epoch 9: 47.55s, train acc=0.93, train loss=0.24, validation acc=0.93, validation loss=0.24
# Epoch 10: 51.96s, train acc=0.93, train loss=0.23, validation acc=0.93, validation loss=0.23
# Epoch 11: 56.40s, train acc=0.94, train loss=0.22, validation acc=0.94, validation loss=0.22
# Epoch 12: 63.37s, train acc=0.94, train loss=0.21, validation acc=0.94, validation loss=0.21
# Epoch 13: 67.77s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.21
# Epoch 14: 72.18s, train acc=0.94, train loss=0.20, validation acc=0.94, validation loss=0.20
# Epoch 15: 78.57s, train acc=0.95, train loss=0.19, validation acc=0.94, validation loss=0.19
# Epoch 16: 83.01s, train acc=0.95, train loss=0.18, validation acc=0.95, validation loss=0.18
# Epoch 17: 88.23s, train acc=0.95, train loss=0.18, validation acc=0.95, validation loss=0.18
# Epoch 18: 93.53s, train acc=0.95, train loss=0.17, validation acc=0.95, validation loss=0.17
# Epoch 19: 97.90s, train acc=0.95, train loss=0.16, validation acc=0.95, validation loss=0.17
# Epoch 20: 103.77s, train acc=0.95, train loss=0.16, validation acc=0.95, validation loss=0.17
#
# Test acc=0.95, Test loss=0.17
#
# Testing combination: Activation=elu, Optimizer=momentum, Learning Rate=0.001
# Epoch 1: 4.61s, train acc=0.63, train loss=1.64, validation acc=0.64, validation loss=1.62
# Epoch 2: 9.05s, train acc=0.74, train loss=1.18, validation acc=0.75, validation loss=1.16
# Epoch 3: 15.90s, train acc=0.80, train loss=0.91, validation acc=0.81, validation loss=0.88
# Epoch 4: 20.29s, train acc=0.83, train loss=0.74, validation acc=0.84, validation loss=0.72
# Epoch 5: 24.61s, train acc=0.85, train loss=0.64, validation acc=0.85, validation loss=0.62
# Epoch 6: 31.53s, train acc=0.86, train loss=0.57, validation acc=0.86, validation loss=0.55
# Epoch 7: 35.87s, train acc=0.87, train loss=0.53, validation acc=0.87, validation loss=0.51
# Epoch 8: 40.37s, train acc=0.87, train loss=0.49, validation acc=0.88, validation loss=0.47
# Epoch 9: 46.51s, train acc=0.88, train loss=0.47, validation acc=0.88, validation loss=0.45
# Epoch 10: 50.87s, train acc=0.88, train loss=0.44, validation acc=0.89, validation loss=0.43
# Epoch 11: 55.82s, train acc=0.88, train loss=0.43, validation acc=0.89, validation loss=0.41
# Epoch 12: 61.39s, train acc=0.89, train loss=0.41, validation acc=0.89, validation loss=0.40
# Epoch 13: 65.76s, train acc=0.89, train loss=0.40, validation acc=0.89, validation loss=0.38
# Epoch 14: 71.41s, train acc=0.89, train loss=0.39, validation acc=0.90, validation loss=0.37
# Epoch 15: 76.16s, train acc=0.89, train loss=0.38, validation acc=0.90, validation loss=0.37
# Epoch 16: 80.54s, train acc=0.90, train loss=0.37, validation acc=0.90, validation loss=0.36
# Epoch 17: 87.10s, train acc=0.90, train loss=0.37, validation acc=0.90, validation loss=0.35
# Epoch 18: 91.40s, train acc=0.90, train loss=0.36, validation acc=0.90, validation loss=0.35
# Epoch 19: 95.68s, train acc=0.90, train loss=0.36, validation acc=0.90, validation loss=0.34
# Epoch 20: 102.46s, train acc=0.90, train loss=0.35, validation acc=0.90, validation loss=0.34
#
# Test acc=0.90, Test loss=0.34
#
# Testing combination: Activation=elu, Optimizer=adam, Learning Rate=0.01
# Epoch 1: 5.44s, train acc=0.96, train loss=0.15, validation acc=0.96, validation loss=0.17
# Epoch 2: 13.05s, train acc=0.96, train loss=0.16, validation acc=0.95, validation loss=0.18
# Epoch 3: 18.42s, train acc=0.97, train loss=0.12, validation acc=0.96, validation loss=0.15
# Epoch 4: 24.15s, train acc=0.97, train loss=0.11, validation acc=0.96, validation loss=0.15
# Epoch 5: 30.96s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.14
# Epoch 6: 36.32s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.14
# Epoch 7: 44.07s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.15
# Epoch 8: 49.40s, train acc=0.98, train loss=0.09, validation acc=0.96, validation loss=0.18
# Epoch 9: 57.05s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.17
# Epoch 10: 62.47s, train acc=0.97, train loss=0.12, validation acc=0.96, validation loss=0.23
# Epoch 11: 69.60s, train acc=0.98, train loss=0.08, validation acc=0.97, validation loss=0.19
# Epoch 12: 75.10s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.17
# Epoch 13: 80.85s, train acc=0.98, train loss=0.11, validation acc=0.97, validation loss=0.23
# Epoch 14: 87.92s, train acc=0.99, train loss=0.05, validation acc=0.97, validation loss=0.18
# Epoch 15: 93.20s, train acc=0.98, train loss=0.09, validation acc=0.97, validation loss=0.24
# Epoch 16: 100.82s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.16
# Epoch 17: 106.09s, train acc=0.99, train loss=0.06, validation acc=0.97, validation loss=0.17
# Epoch 18: 113.89s, train acc=0.99, train loss=0.06, validation acc=0.97, validation loss=0.19
# Epoch 19: 119.24s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.20
# Epoch 20: 125.95s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.17
#
# Test acc=0.97, Test loss=0.17
#
# Testing combination: Activation=elu, Optimizer=adam, Learning Rate=0.001
# Epoch 1: 5.81s, train acc=0.95, train loss=0.16, validation acc=0.95, validation loss=0.17
# Epoch 2: 11.30s, train acc=0.97, train loss=0.10, validation acc=0.97, validation loss=0.12
# Epoch 3: 18.46s, train acc=0.98, train loss=0.07, validation acc=0.97, validation loss=0.10
# Epoch 4: 23.97s, train acc=0.98, train loss=0.06, validation acc=0.97, validation loss=0.09
# Epoch 5: 31.81s, train acc=0.99, train loss=0.04, validation acc=0.98, validation loss=0.08
# Epoch 6: 37.22s, train acc=0.99, train loss=0.04, validation acc=0.97, validation loss=0.09
# Epoch 7: 45.00s, train acc=0.99, train loss=0.03, validation acc=0.97, validation loss=0.08
# Epoch 8: 50.50s, train acc=0.99, train loss=0.02, validation acc=0.98, validation loss=0.08
# Epoch 9: 58.09s, train acc=0.99, train loss=0.02, validation acc=0.98, validation loss=0.08
# Epoch 10: 63.55s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.08
# Epoch 11: 70.31s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.09
# Epoch 12: 76.34s, train acc=1.00, train loss=0.02, validation acc=0.98, validation loss=0.09
# Epoch 13: 81.75s, train acc=1.00, train loss=0.01, validation acc=0.97, validation loss=0.10
# Epoch 14: 89.27s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.11
# Epoch 15: 94.75s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.10
# Epoch 16: 102.29s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.11
# Epoch 17: 107.70s, train acc=1.00, train loss=0.00, validation acc=0.98, validation loss=0.09
# Epoch 18: 115.65s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.10
# Epoch 19: 121.06s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.11
# Epoch 20: 128.66s, train acc=1.00, train loss=0.01, validation acc=0.98, validation loss=0.12
#
# Test acc=0.98, Test loss=0.12

# %% [markdown]
# # MLP as function Approximator
# We know that a MLP with one hidden layer could  approximate any smooth function! <br> Here you will manually fit a sine function using ReLU activation. <br>You need to set the correct weights on ReLUs so the linear combination approximates the desired function.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

def relu_approximation(input_data, target_labels):
    """
    Args:
      input_data: torch.tensor
        Input training data
      target_labels: torch.tensor
        Ground truth labels for training data

    Returns:
      predicted_labels: torch.tensor
        Estimated labels or class predictions
        Derived from weighted sum of ReLU activations along the x-axis
      activation_map: torch.tensor
        ReLU activations computed across the x-axis
      x_points: torch.tensor
        Points along the x-axis
      relu_weights: torch.tensor
        Weights for the ReLU units
    """
    # Number of ReLU units
    num_relus = input_data.shape[0] - 1

    # Generate dense x-axis points for interpolation
    x_points = torch.linspace(torch.min(input_data), torch.max(input_data), 1000)

    # Compute bias for ReLU units
    biases = -input_data[1:].flatten()

    # Initialize activation map to store ReLU activations
    activation_map = torch.zeros((num_relus, len(x_points)))

    for relu_idx in range(num_relus):
        activation_map[relu_idx, :] = torch.clamp(x_points + biases[relu_idx], min=0)

    # Compute slopes between points
    slopes = ((target_labels[1:] - target_labels[:-1]) / (input_data[1:] - input_data[:-1])).flatten()

    # Initialize weights for ReLU units
    relu_weights = torch.zeros(num_relus)
    previous_slope = 0
    for j in range(num_relus):
        delta_slope = slopes[j] - previous_slope
        relu_weights[j] = delta_slope
        previous_slope = slopes[j]

    # Compute predicted labels as weighted sum of ReLU activations
    predicted_labels = (relu_weights @ activation_map) + target_labels[0].item()

    return predicted_labels, activation_map, x_points, relu_weights

# Helper function to plot the approximation
def plot_function_apx(x_points, activation_map, predicted_labels, relu_weights, input_data, target_labels):
    plt.figure(figsize=(12, 8))

    # Top plot: ReLU activations (basis functions)
    plt.subplot(2, 1, 1)
    for i in range(activation_map.shape[0]):
        plt.plot(x_points.numpy(), activation_map[i, :].numpy(), label=f'ReLU {i+1}')
    plt.title('ReLU Activations (Basis Functions)')
    plt.xlabel('x-values')
    plt.ylabel('Activation Levels')
    plt.legend()
    plt.grid(True)

    # Bottom plot: Function approximation vs ground truth
    plt.subplot(2, 1, 2)
    plt.plot(x_points.numpy(), np.sin(x_points.numpy()), label='Ground Truth (sin(x))', color='green')
    plt.plot(x_points.numpy(), predicted_labels.numpy(), label='Predicted Output', linestyle='--', color='red')
    plt.scatter(input_data.numpy(), target_labels.numpy(), label='Training Data', color='black')
    plt.title('Function Approximation vs Ground Truth')
    plt.xlabel('x')
    plt.ylabel('y(x)')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# Generate synthetic training data using sine function
num_samples = 10
input_data = torch.linspace(0, 2 * np.pi, num_samples).view(-1, 1)
target_labels = torch.sin(input_data)

# Compute ReLU-based approximation
predicted_output, activation_map, x_points, relu_weights = relu_approximation(input_data, target_labels)

# Plot the results
plot_function_apx(x_points, activation_map, predicted_output, relu_weights, input_data, target_labels)

# %% [markdown]
# # Depth vs. Width
# Here we wanna see the effect of width vs. depth on a classification task.First you are going to implement MLP again; But with 2 differences: <br>
#
# 1.   It is general purpose (i.e. works for desired depth and activation functions)
# 2.   You will implement it using pytorch

# %%
class MLP_pytorch(nn.Module):
    """
    Simulate MLP Network
    """

    def __init__(self, activation_fn, input_feature_num, hidden_unit_nums, output_feature_num):
        """
        Initialize MLP Network parameters

        Args:
          activation_fn: string
            Activation function ('relu', 'tanh', 'sigmoid', 'leaky_relu', 'elu')
          input_feature_num: int
            Number of input features
          hidden_unit_nums: list
            Number of units per hidden layer. List of integers
          output_feature_num: int
            Number of output features
        """
        super(MLP_pytorch, self).__init__()
        self.input_feature_num = input_feature_num
        self.mlp = nn.Sequential()

        # Map string activation function to PyTorch activation functions
        activation_dict = {
            'relu': nn.ReLU(),
            'tanh': nn.Tanh(),
            'sigmoid': nn.Sigmoid(),
            'leaky_relu': nn.LeakyReLU(),
            'elu': nn.ELU()
        }

        if activation_fn not in activation_dict:
            raise ValueError(f"Unsupported activation function: {activation_fn}")

        activation = activation_dict[activation_fn]

        # Build the layers of the network
        in_num = input_feature_num
        for i, units in enumerate(hidden_unit_nums):
            self.mlp.add_module(f'Linear_{i}', nn.Linear(in_num, units))
            self.mlp.add_module(f'Activation_{i}', activation)
            in_num = units

        # Add the output layer
        out_layer = nn.Linear(in_num, output_feature_num)
        self.mlp.add_module('Output_Linear', out_layer)

    def forward(self, x):
        """
        Simulate forward pass of MLP Network

        Args:
          x: torch.tensor
            Input data

        Returns:
          logits: Instance of MLP
            Forward pass of MLP
        """
        # Reshape inputs to (batch_size, input_feature_num)
        x = x.view(-1, self.input_feature_num)
        logits = self.mlp(x)  # forward pass

        return logits

# %% [markdown]
# Now let's make a spiral dataset that follows this formula:
# \begin{equation}
# \begin{array}{c}
# X_{k}(t)=t\left(\begin{array}{c}
# \sin \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right) \\
# \cos \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right)
# \end{array}\right)
# \end{array}, \quad 0 \leq t \leq 1, \quad k=1, \ldots, K
# \end{equation}
#
# Run cell below to create the data and load it as tensors.

# %%
# @title Data Loader
K = 4
sigma = 0.4
N = 1000
t = torch.linspace(0, 1, N)
X = torch.zeros(K*N, 2)
y = torch.zeros(K*N)
for k in range(K):
  X[k*N:(k+1)*N, 0] = t*(torch.sin(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  X[k*N:(k+1)*N, 1] = t*(torch.cos(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  y[k*N:(k+1)*N] = k


X_test, y_test, X_train, y_train = shuffle_and_split_data(X, y, seed=SEED)

# DataLoader with random seed
batch_size = 128
g_seed = torch.Generator()
g_seed.manual_seed(SEED)

test_data = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_data, batch_size=batch_size,
                         shuffle=False, num_workers=0,
                         worker_init_fn=seed_worker,
                         generator=g_seed,
                         )

train_data = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_data,
                          batch_size=batch_size,
                          drop_last=True,
                          shuffle=True,
                          worker_init_fn=seed_worker,
                          generator=g_seed,
                          )

# %% [markdown]
# Now we will add more polynomial features to the dataset to make the first layer wider. Afterwards, train a single linear layer. We could use the same MLP network with no hidden layers (though it would not be called an MLP anymore!).
#
# Add polynomial terms up to $P=50$ which means that for every $x_1^n x_2^m$ term, $n+m\leq P$. Total number of polynomial features up to $P$ follows this formula:
#
# \begin{equation}
# \text{# of terms} = \frac{(P+1)(P+2)}{2}
# \end{equation}
#
# Also, we don't need the polynomial term with degree zero (which is the constatnt term) since `nn.Linear` layers have bias terms. Therefore we will have one fewer polynomial feature.

# %%
def polynomial_classifier(poly_degree, seed=0):
    """
    Helper function to run the polynomial classifier

    Args:
      poly_degree: int
        Degree of the polynomial
      seed: int
        A non-negative integer that defines the random state.

    Returns:
      num_features: int
        Number of features
    """
    def polynomial_features(poly_degree, X):
        """
        Function to define the number of polynomial features except the bias term

        Args:
          poly_degree: int
            Degree of the polynomial
          X: torch.tensor
            Input data

        Returns:
          num_features: int
            Number of features
          poly_X: torch.tensor
            Polynomial term
        """
        n_samples = X.shape[0]
        num_features = (poly_degree + 1) * (poly_degree + 2) // 2 - 1  # Excluding the bias term
        poly_X = torch.zeros((n_samples, num_features))

        feature_idx = 0
        for n in range(poly_degree + 1):
            for m in range(poly_degree + 1 - n):
                if n + m > 0:  # Skip the bias term (n + m = 0)
                    poly_X[:, feature_idx] = (X[:, 0] ** n) * (X[:, 1] ** m)
                    feature_idx += 1

        return poly_X, num_features

    # Generate polynomial features for train and test sets
    poly_X_test, num_features = polynomial_features(poly_degree, X_test)
    poly_X_train, _ = polynomial_features(poly_degree, X_train)

    batch_size = 128

    g_seed = torch.Generator()
    g_seed.manual_seed(seed)
    poly_test_data = TensorDataset(poly_X_test, y_test.long())
    poly_test_loader = DataLoader(poly_test_data,
                                  batch_size=batch_size,
                                  shuffle=False,
                                  num_workers=1,
                                  worker_init_fn=seed_worker,
                                  generator=g_seed)

    poly_train_data = TensorDataset(poly_X_train, y_train.long())
    poly_train_loader = DataLoader(poly_train_data,
                                   batch_size=batch_size,
                                   shuffle=True,
                                   num_workers=1,
                                   worker_init_fn=seed_worker,
                                   generator=g_seed)

    # Defining a linear model using MLP class
    poly_net = MLP_pytorch('relu', num_features, [], K)

    # Train and test
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(poly_net.parameters(), lr=1e-3)

    # Training loop
    num_epochs = 100
    for epoch in range(num_epochs):
        poly_net.train()
        total_loss = 0
        for x_batch, y_batch in poly_train_loader:
            optimizer.zero_grad()
            logits = poly_net(x_batch)
            loss = criterion(logits, y_batch)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {total_loss / len(poly_train_loader)}")

    # Test performance
    poly_net.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for x_batch, y_batch in poly_test_loader:
            logits = poly_net(x_batch)
            predictions = torch.argmax(logits, dim=1)
            correct += (predictions == y_batch).sum().item()
            total += y_batch.size(0)
    print(f"Test Accuracy: {correct / total * 100:.2f}%")

    # Plot decision boundary
    X_all = sample_grid()
    poly_X_all, _ = polynomial_features(poly_degree, X_all)
    y_pred = poly_net(poly_X_all)

    plot_decision_map(X_all.cpu(), y_pred.cpu(), X_test.cpu(), y_test.cpu())
    plt.show()

    return num_features

# %% [markdown]
# ### Train the network. How does it generalize?

# %%
seed_setter(seed=SEED)
max_poly_deg = 50
num_features = polynomial_classifier(max_poly_deg)
print(f'Number of features: {num_features}')
# Out:
# Random seed 2024 has been set.
# Epoch 10/100, Loss: 1.1033947706222533
# Epoch 20/100, Loss: 0.9809541463851928
# Epoch 30/100, Loss: 0.9014295387268066
# Epoch 40/100, Loss: 0.8430132722854614
# Epoch 50/100, Loss: 0.7967846632003784
# Epoch 60/100, Loss: 0.7582307434082032
# Epoch 70/100, Loss: 0.7250586485862732
# Epoch 80/100, Loss: 0.6958537244796753
# Epoch 90/100, Loss: 0.6696754193305969
# Epoch 100/100, Loss: 0.6459138369560242
# Test Accuracy: 69.88%
# Number of features: 1325

# %% [markdown]
# Now create another instance of `MLP_pytorch` class having a hidden layer of 128 neurons and train it. Compare the result with the wide network. How does deeper model generalize? Is the decision boundaries ideal? Why?

# %%
seed_setter(SEED)

# Create a new MLP with one hidden layer of 128 neurons
net2 = MLP_pytorch(
    activation_fn='relu',  # Activation function for hidden layers
    input_feature_num=2,  # Input features (x, y coordinates)
    hidden_unit_nums=[128],  # One hidden layer with 128 neurons
    output_feature_num=K  # Number of classes (spiral arms)
)

# Define criterion and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net2.parameters(), lr=1e-3)

# Train the model
num_epochs = 100
_, _ = train_test_classification(
    net2,
    criterion,
    optimizer,
    train_loader,
    test_loader,
    num_epochs=num_epochs,
    training_plot=True
)

# Generate predictions on the grid and plot the decision boundary
X_all = sample_grid()
y_pred = net2(X_all).cpu()
plot_decision_map(X_all, y_pred, X_test, y_test)

##############################---TODO---##############################
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 97.84
# Accuracy on the 800 testing samples: 98.38
